# %% [markdown]
# Audio Neural Style Transfer with Pytorch
# ============================
# This is an implementation of neural style transfer using the alogrithm developed in
# [A Neural Algorithm of Artistic Style](https://arxiv.org/abs/1508.06576) by Leon A. Gatys, Alexander S. Ecker and Matthias Bethge.
#
# However instead of learning style from images we use the spectrogram in place to carry out the procedure on audio.
#
# General implementation is based off the [Pytorch tutorial on Neural Transfer](http://pytorch.org/tutorials/advanced/neural_style_tutorial.html) by Alexis Jacq. Also inspired by [Audio texture synthesis](https://github.com/DmitryUlyanov/neural-style-audio-torch) by Dmitry Ulyanov.

# %%
# %matplotlib inline
from __future__ import print_function
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import numpy as np

import librosa
from IPython.display import Audio, display
from PIL import Image

import matplotlib.pyplot as plt
import scipy.stats as stats

import torchvision.transforms as transforms
import torchvision.models as models
from torch.nn.modules.module import _addindent

import copy
import os
import math

#for random feature projection
from scipy.stats import ortho_group


import soundfile as sf
from matplotlib.pyplot import figure

# %%
def log_scale(img):
    img = np.log1p(img)
    return img

def inv_log(img):
    img = np.exp(img) - 1.
    return img

# %% [markdown]
# <div style="background-color: honeydew">
# <h2> Session Parameters </h2>
# </div>

# %%
# True uses PGHI (Truncated Gaussian window, log mag, PGHI reconstruction)
# False uses Log Mag spectrum and Griffin Lim reconstruction
tifresi=False

#STYLE_FILENAME = "inputs/lemons.wav" #input filename
#STYLE_FILENAME = "inputs/gansounds/pops4secs.wav" #input filename
#STYLE_FILENAME = "inputs/gansounds/hubub.10secs.wav" #input filename

#STYLE_FILENAME = "inputs/fm.wav" #input filename
#STYLE_FILENAME = "inputs/peepers.wav" #input filename
#STYLE_FILENAME = "inputs/tokwotal.wav" #input filename
STYLE_FILENAME = "inputs/mcdermott/Tapping 1-2.b.wav" #input filename
#STYLE_FILENAME = "inputs/GAN/test_2D4pt_d1.0_d0.0_v.0.wav" #input filename

# You can have your output length be anything! 
SYNTHETIC_LENGTH_FACTOR = 1 # duration of generated relative to target texture
#Go up to 20000 for high quality if you are on a GPU
num_steps=150 #00 #70

# Streams contribute to error over time steps starting with last stream first.
# progressive_proportion is the number of steps before all streams are contributing to error
progressive_proportion=0 # proportion of steps for all streams to contribute
####################################################################################################
#Gram matrix dot product multiplies: RFMSTACK*(feature_size/RFMSALEFACTOR)^2
RANDOM_PROJECTION= "None" #, "Gaussian", "Sparse"   #(n=None means no random projection at all)
RFMSCALEFACTOR=16   #RM project to size relative to feature dimension
RFMSTACK=32         # how many different RMs to stack
####################################################################################################

#MS Number of separate CNNs operating on input
numStreams=6
learning_Rate= 1 #0.1 #.1  # must be smaller for more streams (if numStream=1, then learning_Rate can be 1)

# %%
display(Audio(STYLE_FILENAME))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <div style="background-color: honeydew">
# <h2> FFT and CNN parameters  </h2>
# (probably don't need to change)
# </div>

# %%
# set filenames
outname = 'rftests' #output dir
variations = 1 # no. of separate outputs (to test consistency), 1 if only want single output

#librosa audio params
N_FFT = 512 
K_HOP = 128 

# architecture
"""use a custom convolutional network randomly initialized""" 
use01scale = False #set to true if want to scale img to [0,1] prior to training. Recommended if using VGG19
boundopt = False #whether to regularize the input within [lower,upper]. Recommended if using VGG19
whichChannel = "freq" #2d=2d conv, 1d options:freq=freq bins as channels, time= time bins as channels 

N_FILTERS = 512# 4096 #no. of filters in 1st conv layer
possible_kernels = [2,4,8,16,32,64,128,256,512,1024,2048]

#N_FILTERS = 128
#possible_kernels = [2,2,2,2,4,4,4,4,8,8,8,8,16,16, 16, 16, 32,32, 32, 32, 64,64, 64, 64, 128, 128, 128, 128 ]# 256,512,1024,2048]

# possible_kernels = [2,4,8,16,32,64,128,256,512,1024,2048]
# possible_kernels = [5,5,5,5,5,5]
hor_filters = [0]*numStreams
for j in range(numStreams):
    hor_filters[j]=possible_kernels[j]

# %% [markdown]
# <div style="background-color: honeydew">
# <h4> TFResi params  </h4>
# (probably don't need to change)
# </div>

# %% [markdown]
# [Link to tfresi code.](https://github.com/andimarafioti/tifresi)

# %%
from tifresi.hparams import HParams
from tifresi.stft import GaussTruncTF

# from tifresi.transforms import log_spectrogram
# from tifresi.transforms import inv_log_spectrogram
#NOTE: Not using Marifioties 10 log_10 transform. Instead use natural log.
# This makes a HUGE difference !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
log_spectrogram=log_scale
inv_log_spectrogram=inv_log

stft_channels = HParams.stft_channels = N_FFT 
hop_size =  HParams.hop_size  = K_HOP
print(f'{hop_size=}')
HParams.sr=16000 

# empirically set: - too small, get low-res ringing; too high, get distortion
tfresiMagSpectScale=1 # Takes the [0,1] mag spectrogram and maps it to [0, tfresiMagSpectScale]

# For faster processin, a truncated window can be used instead
stft_system = GaussTruncTF(hop_size=hop_size, stft_channels=stft_channels)
# Out:
# hop_size=128

# %% [markdown]
# <div style="background-color: honeydew">
# <h4> Plumbing  </h4>
# </div>

# %%
use_cuda = torch.cuda.is_available() #use GPU if available
print('GPU available =',use_cuda)
dtype = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor
# Out:
# GPU available = True

# %%
def read_audio_spectum(filename, tifresi=True):
    #x, fs = librosa.load(filename) #x=audiodata, fs=samplerate
    x, fs  = sf.read(filename)
    print(f'input file sample rate = {fs}')
    print(f'{len(x)=}')
    print(f'{hop_size=}')

#     x=x+np.random.normal(scale=.0001, size=N_SAMPLES)
    print(f'np.mod(len(x), stft_channels) = {np.mod(len(x), stft_channels)}')
    if tifresi :
        #x=np.append(x, np.zeros((hop_size-np.mod(len(x), hop_size))))
        x=np.append(x, np.zeros(stft_channels-np.mod(len(x), stft_channels)))
    print(f'{len(x)=}, {np.mod(len(x), hop_size)=}')
    print(f' number of hops is {len(x)//hop_size}')
    
    #N_SAMPLES = len(x)
    if tifresi :
        print(f'In read audio, doing tifresi spectrogram')
#         R=tfresiMagSpectScale*stft_system.spectrogram(x)
        R=stft_system.spectrogram(x)
    else :
        print(f'In read audio, doing librosa spectrogram')
        R = np.abs(librosa.stft(x, n_fft=N_FFT, hop_length=K_HOP, win_length=N_FFT,  center=False))    
        
    print(f'R range is  [{np.amin(R)}, {np.amax(R)}')
    print(f'K_HOP - {K_HOP} and N_FFT is {N_FFT}')
    print(f'R shape is {R.shape}')
    return R, fs


def findMinMax(img):
    return int(math.floor(np.amin(img))),int(math.ceil(np.amax(img)))

def img_scale(img,datasetMin,datasetMax,scaleMin,scaleMax):
    """scales input numpy array from [datasetMin,datasetMax] -> [scaleMin,scaleMax]"""    
    shift = (scaleMax-scaleMin) / (datasetMax-datasetMin)
    scaled_values = shift * (img-datasetMin) + scaleMin
    print("img_scale: Using [{0},{1}] -> [{2},{3}] for scale conversion".format(datasetMin,datasetMax,scaleMin,scaleMax))
    return scaled_values

def img_invscale(img,datasetMin,datasetMax,scaleMin,scaleMax):
    """scales input numpy array from [scaleMin,scaleMax] -> [datasetMin,datasetMax]"""
    shift = (datasetMax-datasetMin) / (scaleMax-scaleMin)
    scaled_values = shift * (img-scaleMin) + datasetMin
    print("img_invscale: Using [{0},{1}] -> [{2},{3}] for inverse scale conversion".format(scaleMin,scaleMax,datasetMin,datasetMax))
    return scaled_values
    
#if 0
    # use below functions to use librosa db scale, normalized to [0,1]
    # note that this scaling does not work well for style transfer
    def db_scale(img,scale=80):
        img = librosa.amplitude_to_db(img)
        shift = float(np.amax(img))
        img = img - shift #put max at 0
        img = img/scale #scale from [-80,0] to [-1,0]
        img = img + 1. #shift to [0,1]
        img = np.maximum(img, 0) #clip anything below 0
        return img, shift

    def inv_db(img,shift,scale=80):
        img = img - 1. #shift from [0,1] to [-1,0]
        img = img * scale #[-1,0] -> [-80,0]
        img = img + shift
        img = librosa.db_to_amplitude(img)    
        return img

# %% [markdown]
# <div style="background-color: #AAFFAA">
# <h4> Prepare input and inspect.  </h4>
# </div>

# %%
R, fs = read_audio_spectum(STYLE_FILENAME, tifresi)
print(f"raw spectrogram R range before log and scaling: [{np.amin(R)},{np.amax(R)}] ")
# Out:
# input file sample rate = 16000
# len(x)=111428
# hop_size=128
# np.mod(len(x), stft_channels) = 324
# len(x)=111428, np.mod(len(x), hop_size)=68
#  number of hops is 870
# In read audio, doing librosa spectrogram
# R range is  [2.7971532049993745e-06, 8.463823396576199
# K_HOP - 128 and N_FFT is 512
# R shape is (257, 867)
# raw spectrogram R range before log and scaling: [2.7971532049993745e-06,8.463823396576199]

# %%
if tifresi :
    print('TIFResi: log_spectrogram')
    a_style = log_spectrogram(R)
    
else :
    print('HUZ: log_scase')
    a_style = log_scale(R)
    
print(f"    LOG    range before scaling: [{np.amin(a_style)},{np.amax(a_style)}]",)
print(f'shape of a_style is {a_style.shape}')
# Out:
# HUZ: log_scase
#     LOG    range before scaling: [2.7971492929736436e-06,2.247476465954237]
# shape of a_style is (257, 867)

# %%
if use01scale == True:
    a_min,a_max = findMinMax(a_style)
    a_style = img_scale(a_style,a_min,a_max,0,1)

# %%
"""we plot out the STFT magnitude range and the spectrogram do get a feel of the data"""
#plt.ion()
fig = plt.figure()
plt.title('Histogram of log Style Spectrogram vals')
ax = fig.add_subplot(111)
#n,b,_ = ax.hist(a_style.flatten(),bins='auto')
n,b,_ = ax.hist(a_style.flatten(),bins=100)
#ax.set_yticklabels([])
#ax.set_xticks([])
maxbin = np.argmax(n)
plt.show()
print("Max bin:",b[maxbin])

plt.figure(figsize=(10, 5))
plt.title('Style spectrogram')
plt.imshow(a_style, origin='lower')
print("Style spectrogram range after scaling:",np.amin(a_style),np.amax(a_style))
print("mean and std = ",np.mean(a_style),np.std(a_style))
temp_a_style=a_style # for reality check in next cell
# Out:
# Max bin: 2.7971492929736436e-06
# Style spectrogram range after scaling: 2.7971492929736436e-06 2.247476465954237
# mean and std =  0.06033450013220179 0.19112182260534913

# %%
if 0 : #RUN PGHI ON THE ORIGINAL INPUT DATA SPECTROGRAM  - ASSUMING TFRESI for the little experiment in this cell
    # now invert it, just like we will do with the GAN-generated images

    #SPECTOFFSET
    SPECTOFFSET=0 #.25

    lspect=a_style
    print(f' shape of lspect is {lspect.shape}')
    print(use01scale)
    
    #ASSUMING TIFRES
    print('TIFResi: inv_log_spectrogram')
    if use01scale == True:
#         foo = img_invscale(lspect,a_min,a_max,0,1)
        out_spec = inv_log_spectrogram(lspect+ SPECTOFFSET) 
#         print(f'   RESCALED: Min/Max of outputs:  {np.amin(out_spec)},{np.amax(out_spec)}') # check values make sense

    else:
        out_spec =inv_log_spectrogram(lspect+SPECTOFFSET) 
#         print(f'   inv_log_spectrogram: Min/Max of outputs:  {np.amin(out_spec)},{np.amax(out_spec)}') # check values make sense

    print(f' shape of out_spec is {out_spec.shape}')
#     bar = np.clip(out_spec, 0,None)
#     print(f' shape of bar is {bar.shape}')

#     print(f'Min/Max of spectrogram: {np.amin(bar)}, {np.amax(bar)}') # check values make sense
    x = stft_system.invert_spectrogram(out_spec) 

    display(Audio(x, rate=16000, autoplay=True))

# %%
N_FRAMES = a_style.shape[1] #time bins
N_FREQ = a_style.shape[0] #freq bins


a_style = np.ascontiguousarray(a_style[None,None,:,:]) #[batch,channels,freq,samples]
if whichChannel == "2d":
    a_style = torch.from_numpy(a_style) #pytorch:[batch,channels(1),height(freq),width(samples)]
elif whichChannel == "freq":
    a_style = torch.from_numpy(a_style).permute(0,2,1,3) #pytorch:[batch,channels(freq),height(1),width(samples)]
elif whichChannel == "time":
    a_style = torch.from_numpy(a_style).permute(0,3,1,2) #pytorch:[batch,channels(samples),height(1),width(freq)]

style_img = Variable(a_style).type(dtype) #convert to pytorch variable
print("Using whichChannel ==",whichChannel," Input shape:",style_img.data.shape) #check shape is correct
# Out:
# Using whichChannel == freq  Input shape: torch.Size([1, 257, 1, 867])

# %%
def tensorSpect2np(tensor, n_freqs, n_samples, channels=1) : 
    image = tensor.clone().cpu()  # we clone the tensor to not do changes on it
    if whichChannel == "2d":
        image = image
    if whichChannel == "freq":
        image = image.permute(0,2,1,3).contiguous() # get the dimensions in proper order
    elif whichChannel == "time":
        image = image.permute(0,2,3,1).contiguous() # get the dimensions in proper order
    image = image.view(n_freqs, n_samples)  # remove the fake batch dimension
    
    return image.numpy() #convert pytorch tensor to numpy array

# %%
def imshow(tensor, n_freqs, n_samples, channels=1, title=None, origin='lower'):
    """ transforms pytorch tensor to numpy array and plots it out """
    
    image = tensorSpect2np(tensor, n_freqs, n_samples, channels) #convert pytorch tensor to numpy array
    print(image.shape) #check shape
    print("Output range:",np.amin(image),np.amax(image))
    print("mean and sigma:",np.mean(image),np.std(image))
    
    
    plt.imshow(image, origin=origin)
    if title is not None:
        plt.title(title)
    plt.pause(0.001) # pause a bit so that plots are updated
    return image #return numpy array

"Just to check we can get back the numpy array with the correct shape"
plt.figure(figsize=(10, 5))
plt.figure()
_=imshow(style_img.data, N_FREQ, N_FRAMES, title='Style Spectrogram', origin='lower')

#plt.figure()
#imshow(content_img.data, title='Content Image')
# Out:
# (257, 867)
# Output range: 2.7971494e-06 2.2474766
# mean and sigma: 0.060334504 0.19112183

# %% [markdown]
# <div style="background-color: #FF4488">
# <h4> BeginNetwork   </h4>
# </div>

# %% [markdown]
# <div style="background-color: #AAFFAA">
# <h4> Create network   </h4>
# </div>

# %%
# CREATE NETWORK 
"Here we create the custom network"
import collections as c

if whichChannel == "2d":
    IN_CHANNELS = 1
elif whichChannel == "freq":
    IN_CHANNELS = N_FREQ
elif whichChannel == "time":
    IN_CHANNELS = N_FRAMES
    

# custom weights initialization
def weights_init(m,hor_filter):
    std = np.sqrt(2) * np.sqrt(2.0 / ((N_FREQ + N_FILTERS) * hor_filter))
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
#         torch.nn.init.xavier_uniform_(m.weight)
#         m.bias.data.fill_(0.01)
        m.weight.data.normal_(0.0, std)

class style_net(nn.Module):
    """Here create the network you want to use by adding/removing layers in nn.Sequential"""
    def __init__(self,hor_filter):
        super(style_net, self).__init__()
#         self.hor_filter=hor_filter
        self.layers = nn.Sequential(c.OrderedDict([
                            #('conv1',nn.Conv2d(IN_CHANNELS,N_FILTERS,kernel_size=(1,hor_filter),padding='same', padding_mode='circular', bias=False)),
                            ('conv1',nn.Conv2d(IN_CHANNELS,N_FILTERS,kernel_size=(1,hor_filter),padding='valid', padding_mode='circular', bias=False)),
                            ('relu1',nn.ReLU())#,
#                             ('max1', nn.MaxPool2d(kernel_size=(1,2))),
            
#                             ('conv2',nn.Conv2d(N_FILTERS,N_FILTERS//2,kernel_size=(1,hor_filter),bias=False)),
#                             ('relu2',nn.ReLU()),
#                             ('max2', nn.MaxPool2d(kernel_size=(1,2))),
            
#                             ('conv3',nn.Conv2d(N_FILTERS//2,N_FILTERS//4,kernel_size=(1,hor_filter),bias=False)),
#                             ('relu3',nn.ReLU())
        ]))

                            #('relu2',nn.ReLU()),
                            #('max2', nn.MaxPool2d(kernel_size=(1,2))),


                            #('conv3',nn.Conv2d(N_FILTERS//2,N_FILTERS//2,kernel_size=(1,hor_filter),bias=False)),
                            #('relu3',nn.ReLU()),
                            #('max3', nn.MaxPool2d(kernel_size=(1,2))),

                            #('conv4',nn.Conv2d(N_FILTERS//2,N_FILTERS//4,kernel_size=(1,hor_filter),bias=False)),
                            #('relu4',nn.ReLU()),
                            #('max4', nn.MaxPool2d(kernel_size=(1,2))),


                            #('conv5',nn.Conv2d(N_FILTERS//4,N_FILTERS//4,kernel_size=(1,hor_filter),bias=False)),
                            #('relu5',nn.ReLU()),
                            #('max5', nn.MaxPool2d(kernel_size=(1,2))),


                            #('conv6',nn.Conv2d(N_FILTERS//4,N_FILTERS//8,kernel_size=(1,hor_filter),bias=False)),
                            #('relu6',nn.ReLU())]))

    def forward(self,input):
        out = self.layers(input)
        return out
    
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~    
cnnlist=[] 
#MS create a separate CNN for each stream
for j in range(numStreams) :
    cnn = style_net(hor_filters[j])
    cnn.apply(lambda x, f=hor_filters[j]: weights_init(x,f))
    for param in cnn.parameters():
        param.requires_grad = False
    print(list(cnn.layers))

    # move it to the GPU if possible:
    if use_cuda:
        cnn = cnn.cuda()
    
    cnnlist.append(cnn)

# Add the style/content loss 'layer' after the specified layer:
content_layers_default = [] #ignore for now
# style_layers_default = ['relu_1']
style_layers_default = ['relu_1']
# Out:
# [Conv2d(257, 512, kernel_size=(1, 2), stride=(1, 1), padding=valid, bias=False, padding_mode=circular), ReLU()]
# [Conv2d(257, 512, kernel_size=(1, 4), stride=(1, 1), padding=valid, bias=False, padding_mode=circular), ReLU()]
# [Conv2d(257, 512, kernel_size=(1, 8), stride=(1, 1), padding=valid, bias=False, padding_mode=circular), ReLU()]
# [Conv2d(257, 512, kernel_size=(1, 16), stride=(1, 1), padding=valid, bias=False, padding_mode=circular), ReLU()]
# [Conv2d(257, 512, kernel_size=(1, 32), stride=(1, 1), padding=valid, bias=False, padding_mode=circular), ReLU()]
# [Conv2d(257, 512, kernel_size=(1, 64), stride=(1, 1), padding=valid, bias=False, padding_mode=circular), ReLU()]

# %% [markdown]
# Content loss
# ~~~~~~~~~~~~
#
# The content loss is a function that takes as input the feature maps
# $F_{XL}$ at a layer $L$ in a network fed by $X$ and
# return the weigthed content distance $w_{CL}.D_C^L(X,C)$ between
# this image and the content image. Hence, the weight $w_{CL}$ and
# the target content $F_{CL}$ are parameters of the function. We
# implement this function as a torch module with a constructor that takes
# these parameters as input. The distance $\|F_{XL} - F_{YL}\|^2$ is
# the Mean Square Error between the two sets of feature maps, that can be
# computed using a criterion ``nn.MSELoss`` stated as a third parameter.
#
# We will add our content losses at each desired layer as additive modules
# of the neural network. That way, each time we will feed the network with
# an input image $X$, all the content losses will be computed at the
# desired layers and, thanks to autograd, all the gradients will be
# computed. For that, we just need to make the ``forward`` method of our
# module returning the input: the module becomes a ''transparent layer''
# of the neural network. The computed loss is saved as a parameter of the
# module.
#
# Finally, we define a fake ``backward`` method, that just call the
# backward method of ``nn.MSELoss`` in order to reconstruct the gradient.
# This method returns the computed loss: this will be useful when running
# the gradient descent in order to display the evolution of style and
# content losses.

# %%
class ContentLoss(nn.Module):
    """Since doing texture only we ignore this for now"""

    def __init__(self, target, weight): #weight here is the epsilon tuning (how much content vs style)
        super(ContentLoss, self).__init__()
        # we 'detach' the target content from the tree used
        self.target = target.detach() * weight
        # to dynamically compute the gradient: this is a stated value,
        # not a variable. Otherwise the forward method of the criterion
        # will throw an error.
        self.weight = weight
        self.criterion = nn.MSELoss()

    def forward(self, input):
        self.loss = self.criterion(input * self.weight, self.target)
        self.output = input
        return self.output

    def backward(self, retain_variables=True):
        self.loss.backward(retain_variables=retain_variables)
        return self.loss

# %% [markdown]
# .. Note::
#    **Important detail**: this module, although it is named ``ContentLoss``,
#    is not a true PyTorch Loss function. If you want to define your content
#    loss as a PyTorch Loss, you have to create a PyTorch autograd Function
#    and to recompute/implement the gradient by the hand in the ``backward``
#    method.
#
# Style loss
# ~~~~~~~~~~
#
# For the style loss, we need first to define a module that compute the
# gram produce $G_{XL}$ given the feature maps $F_{XL}$ of the
# neural network fed by $X$, at layer $L$. Let
# $\hat{F}_{XL}$ be the re-shaped version of $F_{XL}$ into a
# $K$\ x\ $N$ matrix, where $K$ is the number of feature
# maps at layer $L$ and $N$ the lenght of any vectorized
# feature map $F_{XL}^k$. The $k^{th}$ line of
# $\hat{F}_{XL}$ is $F_{XL}^k$. We let you check that
# $\hat{F}_{XL} \cdot \hat{F}_{XL}^T = G_{XL}$. Given that, it
# becomes easy to implement our module:

# %%
# create random feature projection matrix
RFM={}

# This is the "sparse" Achlioptas matrix
if RANDOM_PROJECTION=="Sparse" : 
    #RFM[1024]=torch.from_numpy(np.random.choice(np.sqrt(3)*np.array([1., 0., -1.]), (1024,int(1024/RFMSCALEFACTOR)), p=[1./6.,2./3., 1./6.])).type(dtype)
    RFM[512]=torch.from_numpy(np.random.choice(np.sqrt(3)*np.array([1., 0., -1.]), (512,int(512/RFMSCALEFACTOR)), p=[1./6.,2./3., 1./6.])).type(dtype)
    #RFM[256]=torch.from_numpy(np.random.choice(np.sqrt(3)*np.array([1., 0., -1.]), (256,int(256/RFMSCALEFACTOR)), p=[1./6.,2./3., 1./6.])).type(dtype)
    #RFM[128]=torch.from_numpy(np.random.choice(np.sqrt(3)*np.array([1., 0., -1.]), (128,int(128/RFMSCALEFACTOR)), p=[1./6.,2./3., 1./6.])).type(dtype)

#Full orthonormal gaussian 
if RANDOM_PROJECTION=="Gaussian" : 
    #RFM[1024]=(torch.from_numpy(ortho_group.rvs(1024)[:int(1024/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)
    RFM[512]= (torch.from_numpy(ortho_group.rvs(512)[: int(512/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)
    #RFM[256]= (torch.from_numpy(ortho_group.rvs(256)[: int(256/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)
    #RFM[128]= (torch.from_numpy(ortho_group.rvs(128)[: int(128/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)
    for rm in range(1, RFMSTACK) : 
        #RFM[1024]= torch.cat( (RFM[1024], (torch.from_numpy(ortho_group.rvs(1024)[:int(1024/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)), dim=0)
        RFM[512]=torch.cat( (RFM[512],    (torch.from_numpy(ortho_group.rvs(512)[ :int(512/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)), dim=0)
        #RFM[256]=torch.cat( (RFM[256],    (torch.from_numpy(ortho_group.rvs(256)[ :int(256/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)), dim=0)
        #RFM[128]=torch.cat( (RFM[128],    (torch.from_numpy(ortho_group.rvs(128)[ :int(128/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)), dim=0)

# %%
class GramMatrix(nn.Module):

    def forward(self, input):
        a, b, c, d = input.size() #a=batch size(=1)
                                  #b=number of feature maps
                                  #(c,d)=dimensions of a feat. map (N=c*d) -> for 1D conv c=1
        #features = input.view(a * b, c * d)  # resise F_XL into \hat F_XL
        features = input.view(b, a * c * d)  # resise F_XL into \hat F_XL
        
       # features2=torch.matmul(RFM[:b//2,:b], features)
        if RANDOM_PROJECTION=="None":
            features2=features.unsqueeze(0)
        else :
            features2=torch.matmul(RFM[b], features)
        #print(f"In GramMatrix, shape of features = {np.shape(features2)}")

        #G = torch.matmul(features2, features2.t())  # compute the gram product #normalizing? - length of the features
        G = torch.matmul(features2, torch.transpose(features2, 1,2))  # compute the gram product #normalizing? - length of the features
        #print(f"In GramMatrix, shape of grammatrix = {np.shape(G)}")
        # we 'normalize' the values of the gram matrix
        # by dividing by the number of element in each feature maps.
        return G.div(a * c * d)

# %%
class GramMatrix_justfoolinaround_notused(nn.Module):
#class GramMatrix(nn.Module):
    def forward(self, input, recurse=2):
        if recurse==0 :
            return input
        
        a, b, c, d = input.size() #a=batch size(=1)
                                  #b=number of feature maps
                                  #(c,d)=dimensions of a feat. map (N=c*d) -> for 1D conv c=1
        #features = input.view(a * b, c * d)  # resise F_XL into \hat F_XL
        features = input.view(b, a * c * d)  # resise F_XL into \hat F_XL
        
        ##print(f"Grammatrix.forward: {input.size() =}")
        
       # features2=torch.matmul(RFM[:b//2,:b], features)
        if RANDOM_PROJECTION=="None":
            features2=features.unsqueeze(0)
        else :
            features2=torch.matmul(RFM[b], features)
        #print(f"In GramMatrix, shape of features = {np.shape(features2)}")

        #G = torch.matmul(features2, features2.t())  # compute the gram product #normalizing? - length of the features
        G = torch.matmul(features2, torch.transpose(features2, 1,2))  # compute the gram product #normalizing? - length of the features
        #print(f"In GramMatrix, shape of grammatrix = {np.shape(G)}")
        # we 'normalize' the values of the gram matrix
        # by dividing by the number of element in each feature maps.
        ##print(f"Grammatrix.forward: {G.div(a * c * d).size() =}")
        aa, bb, cc = G.size()
        return self.forward(G.div(a * c * d).reshape(1,bb*cc,1,aa), recurse=recurse-1)

# %% [markdown]
# The longer is the feature maps dimension $N$, the bigger are the
# values of the gram matrix. Therefore, if we don't normalize by $N$,
# the loss computed at the first layers (before pooling layers) will have
# much more importance during the gradient descent. We dont want that,
# since the most interesting style features are in the deepest layers!
#
# Then, the style loss module is implemented exactly the same way than the
# content loss module, but we have to add the ``gramMatrix`` as a
# parameter:

# %%
#foofoo
class StyleLoss(nn.Module):

    def __init__(self, target, weight, layer): #weight here is the alpha tuning (how much content vs style)
        super(StyleLoss, self).__init__()
        self.target = target.detach() * weight
        self.weight = weight
        self.gram = GramMatrix()
        self.criterion = nn.MSELoss(size_average=False)
        #print(f'Creating StyleLoss module - this one for layer {layer} with target shape {target.shape}' )


    def forward(self, input):
        #print(f' StyleLoss.forward with input of shape {input.shape}')
        self.output = input.clone()
        self.G = self.gram(input)
        self.G.mul_(self.weight)
        self.loss = self.criterion(self.G, self.target) #/sum(sum(self.target**2)) #target=gram mat for style img, G=gram mat for current input ie. noise
        return self.output

    def backward(self, retain_variables=True):
        self.loss.backward(retain_graph=True)
        return self.loss

# %%
class OptReg(nn.Module):
    """soft bound the optimization between [lower,upper] by regularization"""
    
    def __init__(self, upper, lower, weight=1): #weight here is the alpha tuning (how much content vs style)
        super(OptReg, self).__init__()
        self.upper = Variable(torch.cuda.FloatTensor([upper]))
        self.lower = Variable(torch.cuda.FloatTensor([lower]))
        self.weight = weight

    def forward(self, input):
        #self.output = input.clone()
        self.zeros = Variable(torch.zeros(input.size()).type(dtype))
                              
        self.over = torch.max(input-self.upper,self.zeros)
        self.under = torch.max(self.lower-input,self.zeros)
        self.total= self.over + self.under
        self.l2total = self.weight * self.total.norm(2)
        #print(f'OptReg l2total = {self.l2total}')
        return self.l2total

# %% [raw]
# a = Variable(torch.cuda.FloatTensor([[2,0,2],[1,0,1]]))
# b = Variable(torch.cuda.FloatTensor([[5,0,5],[-1,0,-1]]))
# c = Variable(torch.cuda.FloatTensor([1]))
# d = c-a
# print(d)
# e = torch.max(d,b)
# f = e+e
# print(f)
# g = f.norm(2)
# print(g)
#
# def optbound_regularizer_old(img,upper,lower):
#     """soft bound the optimization between [lower,upper] by regularization"""
#     #print(torch.max(img),torch.min(img))
#     imgn = Variable(img)
#     over = torch.max(imgn.data-upper,torch.zeros(img.size()).type(dtype))
#     #print("over",over)
#     under = torch.max(lower-imgn.data,torch.zeros(img.size()).type(dtype))
#     #print("under",under)
#     out = over + under
#     #print("out",out)
#     out = out.norm(2)
#     #print("norm",out)
#     #l2_reg = torch.cuda.FloatTensor([out])
#     l2_reg = Variable(torch.cuda.FloatTensor([out]), requires_grad=True)
#
#     return l2_reg
#
# def optbound_regularizer(img,upper,lower,reg_weight):
#     """soft bound the optimization between [lower,upper] by regularization"""
#     #print(torch.max(img),torch.min(img))
#     zero_var = Variable(torch.zeros(img.size()).type(dtype))
#     over = Variable(torch.max(img-upper,torch.zeros(img.size()).type(dtype)), requires_grad=True)
#     crit_over = nn.MSELoss(size_average=False)
#     over_loss = crit_over(over,zero_var)
#     #print("over",over)
#     under = Variable(torch.max(lower-img,torch.zeros(img.size()).type(dtype)), requires_grad=True)
#     crit_under = nn.MSELoss(size_average=False)
#     under_loss = crit_under(under,zero_var)
#     #print("under",under)
#     out = over_loss + under_loss
#     #print("out",out)
#     #out = out.norm(2)
#     #print("norm",out)
#     #l2_reg = torch.cuda.FloatTensor([out])
#     #l2_reg = Variable(torch.cuda.FloatTensor([out]), requires_grad=True)
#     out = reg_weight * out
#     #optbound = out.backward(retain_graph=True)
#
#     return out #optbound

# %% [markdown]
# Load the neural network
# ~~~~~~~~~~~~~~~~~~~~~~~
#
# Now, we have to import a pre-trained neural network. As in the paper, we
# are going to use a pretrained VGG network with 19 layers (VGG19).
#
# PyTorch's implementation of VGG is a module divided in two child
# ``Sequential`` modules: ``features`` (containing convolution and pooling
# layers) and ``classifier`` (containing fully connected layers). We are
# just interested by ``features``:

# %% [markdown]
# A ``Sequential`` module contains an ordered list of child modules. For
# instance, ``vgg19.features`` contains a sequence (Conv2d, ReLU,
# Maxpool2d, Conv2d, ReLU...) aligned in the right order of depth. As we
# said in *Content loss* section, we wand to add our style and content
# loss modules as additive 'transparent' layers in our network, at desired
# depths. For that, we construct a new ``Sequential`` module, in wich we
# are going to add modules from ``vgg19`` and our loss modules in the
# right order:

# %%
#rebuild network with the layers we want
def get_style_model_and_losses(cnn, style_img, content_img=None,
                               style_weight=1, content_weight=0,
                               content_layers=content_layers_default,
                               style_layers=style_layers_default, style_img2=None):
    cnn = copy.deepcopy(cnn)

    # just in order to have an iterable access to or list of content/syle losses
    content_losses = []
    style_losses = []
    
    model = nn.Sequential()
    layer_list = list(cnn.layers)
    
    gram = GramMatrix()  # we need a gram module in order to compute style targets

    # move these modules to the GPU if possible:
    if use_cuda:
        model = model.cuda()
        gram = gram.cuda()

    #here we rebuild the network adding the in content and style loss "layers"   
    i = 1  
    for layer in layer_list:

        
        if isinstance(layer, nn.Conv2d): #if layer in vgg19 belong to class nn.Conv2d
            name = "conv_" + str(i)
            model.add_module(name, layer) #add that layer to our sequential model
            
            if content_img != None:
                if name in content_layers: #at the right depth add the content loss "layer"
                    # add content loss:
                    target = model(content_img).clone()
                    content_loss = ContentLoss(target, content_weight)
                    model.add_module("content_loss_" + str(i), content_loss)
                    content_losses.append(content_loss)

            if name in style_layers: #at the right depth add the content loss "layer"
                # add style loss:
                target_feature = model(style_img).clone()
                target_feature_gram = gram(target_feature)
                style_loss = StyleLoss(target_feature_gram, style_weight, name)
                model.add_module("style_loss_" + str(i), style_loss)
                style_losses.append(style_loss)

        if isinstance(layer, nn.ReLU): #do the same for ReLUs
            name = "relu_" + str(i)
            model.add_module(name, layer)
            
            if content_img != None:
                if name in content_layers:
                    # add content loss:
                    target = model(content_img).clone()
                    content_loss = ContentLoss(target, content_weight)
                    model.add_module("content_loss_" + str(i), content_loss)
                    content_losses.append(content_loss)

            if name in style_layers:
                # add style loss:
                target_feature = model(style_img).clone()
                target_feature_gram = gram(target_feature)
                
                
                if 0 : # Replace target with Random Symmetric matrix by shuffling
                    
                    #test to see if random symmetric Gram Matrix can be matched with style transfer iteration
                    # randomly shuffle Gram stack
                    print(f'(Before) TARGET SYMMETRY? {((target_feature_gram.transpose(1, 2) == target_feature_gram).all())=}')
                    
                    #shuffle
                    idx = torch.randperm(target_feature_gram.nelement())
                    target_feature_gram = target_feature_gram.view(-1)[idx].view(target_feature_gram.size())
                    print(f'{target_feature_gram.size()=}')
                    #symmeterize
                    target_feature_gram=(target_feature_gram + target_feature_gram.transpose(1, 2))/2

                    print(f'(After) TARGET SYMMETRY? {((target_feature_gram.transpose(1, 2) == target_feature_gram).all())=}')
                
                
                style_loss = StyleLoss(target_feature_gram, style_weight, name)
                model.add_module("style_loss_" + str(i), style_loss)
                style_losses.append(style_loss) 
                
            i += 1

        if isinstance(layer, nn.MaxPool2d): #do the same for maxpool
            name = "pool_" + str(i)
            model.add_module(name, layer)
            
            if name in style_layers:
                # add style loss:
                target_feature = model(style_img).clone()
                target_feature_gram = gram(target_feature)
                style_loss = StyleLoss(target_feature_gram, style_weight, name)
                model.add_module("style_loss_" + str(i), style_loss)
                style_losses.append(style_loss)
            
            #avgpool = nn.AvgPool2d(kernel_size=(1,2),
            #                stride=layer.stride, padding = layer.padding)
            #model.add_module(name, avgpool)  # *** can also replace certain layers if we want eg. maxpool -> avgpool


    #for param in model.parameters():
    #    param.requires_grad = False
    return model, style_losses, content_losses

# %% [markdown]
# .. Note::
#    In the paper they recommend to change max pooling layers into
#    average pooling. With AlexNet, that is a small network compared to VGG19
#    used in the paper, we are not going to see any difference of quality in
#    the result. However, you can use these lines instead if you want to do
#    this substitution:
#
#    ::
#
#        # avgpool = nn.AvgPool2d(kernel_size=layer.kernel_size,
#        #                         stride=layer.stride, padding = layer.padding)
#        # model.add_module(name,avgpool)

# %% [markdown]
# Input image
# ~~~~~~~~~~~
#
# Again, in order to simplify the code, we take an image of the same
# dimensions than content and style images. This image can be a white
# noise, or it can also be a copy of the content-image.

# %% [markdown]
# <div style="background-color: #AAFFAA">
# <h4> Prepare noise as input  </h4>
# </div>

# %%
"""image to input in generative network"""
#input_img = content_img.clone()

# if you want to use a white noise instead uncomment the below line:
#input_img = Variable(torch.randn(content_img.data.size())).type(dtype)

def in_img(n_freqs, nsamples):
    """initialize (variations) number of unique random noise input images"""  
    input_imgs = []
    print(f'in_img nsamples = {nsamples}')
    #rand_tensor = torch.randn(1,n_freqs,1,nsamples)*1e-3
#     lower,upper,mu,sigma = 1e-3,1,.5,1e-1
#     lower,upper,mu,sigma = -50,0,-45,7
    lower,upper,mu,sigma = 1e-9,0.7,0.001,0.01

    dist = stats.truncnorm((lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma)
    
    i = 0
    while i < variations:
         #[batch,channels,h,w]
        if whichChannel == "2d":
            samples = dist.rvs([1,1,n_freqs,nsamples])
            input_imgs.append(Variable(torch.from_numpy(samples)).type(dtype))
            #input_imgs.append(Variable(torch.rand(1,1,n_freqs,nsamples)*1e-3).type(dtype))
            #input_imgs.append(Variable(torch.randn(1,1,n_freqs,nsamples)*1e-3).type(dtype))
        if whichChannel == "freq":
            #samples = dist.rvs([1,n_freqs,1,nsamples])
            #input_imgs.append(Variable(torch.from_numpy(samples)).type(dtype))
            #input_imgs.append(Variable(torch.rand(1,n_freqs,1,nsamples)*1e-3).type(dtype))
            input_imgs.append(Variable(mu+torch.randn(1,n_freqs,1,nsamples)*1e-2).type(dtype))
        elif whichChannel == "time":
            samples = dist.rvs([1,nsamples,1,n_freqs])
            input_imgs.append(Variable(torch.from_numpy(samples)).type(dtype))
            #input_imgs.append(Variable(torch.rand(1,nsamples,1,n_freqs)*1e-3).type(dtype))
            #input_imgs.append(Variable(torch.randn(1,nsamples,1,n_freqs)*1e-3).type(dtype))
        i +=1
    return input_imgs

input_imgs = in_img(N_FREQ, int(N_FRAMES*SYNTHETIC_LENGTH_FACTOR))

# add the original input image to the figure:
plt.figure()
_=imshow(input_imgs[0].data, N_FREQ, int(N_FRAMES*SYNTHETIC_LENGTH_FACTOR), title='Input Image')
# Out:
# in_img nsamples = 867
# (257, 867)
# Output range: -0.04283742 0.04673088
# mean and sigma: 0.0009951944 0.009992459

# %% [markdown]
# Gradient descent
# ~~~~~~~~~~~~~~~~
#
# As Leon Gatys, the author of the algorithm, suggested
# `here <https://discuss.pytorch.org/t/pytorch-tutorial-for-neural-transfert-of-artistic-style/336/20?u=alexis-jacq>`__,
# we will use L-BFGS algorithm to run our gradient descent. Unlike
# training a network, we want to train the input image in order to
# minimise the content/style losses. We would like to simply create a
# PyTorch  L-BFGS optimizer, passing our image as the variable to optimize.
# But ``optim.LBFGS`` takes as first argument a list of PyTorch
# ``Variable`` that require gradient. Our input image is a ``Variable``
# but is not a leaf of the tree that requires computation of gradients. In
# order to show that this variable requires a gradient, a possibility is
# to construct a ``Parameter`` object from the input image. Then, we just
# give a list containing this ``Parameter`` to the optimizer's
# constructor:

# %%
def get_input_param_optimizer(input_img):
    # this line to show that input is a parameter that requires a gradient
    input_param = nn.Parameter(input_img.data)
    optimizer = optim.LBFGS([input_param])
    return input_param, optimizer

# %% [markdown]
# **Last step**: the loop of gradient descent. At each step, we must feed
# the network with the updated input in order to compute the new losses,
# we must run the ``backward`` methods of each loss to dynamically compute
# their gradients and perform the step of gradient descent. The optimizer
# requires as argument a "closure": a function that reevaluates the model
# and returns the loss.

# %%
#def map(x,a,b,m,n) :
#    if x<=a : return m
#    if x>=b : return n
#    return n+ (m-n)*(x-a)/(b-a)
def map(x,a) :
    if x <= a : return 0
    else  : return 1

# %%
def run_style_transfer(cnnlist, style_img, input_img, content_img=None, num_steps=num_steps,
                       style_weight=1, content_weight=0, reg_weight=0.01): 
    """Run the style transfer"""
    print(f'run_style_transfer: cnnlist is {cnnlist}' )
    
    #MS - one model, loss accumulator, and optimizer per stream 
    modelMS=[None for j in range(numStreams)]
    style_lossesMS=[None for j in range(numStreams)] 
    content_lossesMS=[None for j in range(numStreams)]
#     optimizerMS=[None for j in range(numStreams)]

    #MS one input_param for all streams, each operating on the same data. 
    input_param = nn.Parameter(input_img.data)
    
    
    prev = input_param.data
    
    # first create the separate cnn models and losses
    for j in range(numStreams) :
        print('Building the style transfer model..')
        modelMS[j], style_lossesMS[j], content_lossesMS[j] = get_style_model_and_losses(cnnlist[j],
            style_img, content_img, style_weight, content_weight)
        #input_paramMS[j], optimizerMS[j] = get_input_param_optimizer(input_img)
        print(f'CREATING, style_lossesMS is {style_lossesMS}')
        #input_param is the same variable passed to each separate CNN
        #MS Changed learning rate to prevent instabilities with lr=1.
#         optimizerMS[j] = optim.LBFGS([input_param], lr=learning_Rate)

        print("Input range:",torch.max(input_param.data),torch.min(input_param.data))   
        print(modelMS[j])
        print('Optimizing..')
    optimizerMS = optim.LBFGS([input_param],lr=learning_Rate)
        
    
    print(f'Created {j} MS models')
    # print(f' input_param[0] is input_param[1] ? ...... {input_paramMS[0] is input_paramMS[1]}')    # FALSE!    
    

    step = [0]
    
    if boundopt == True:
        bound = OptReg(1,0.005, reg_weight)
    

    plt.figure()
    while step[0] <= num_steps:

        step[0] += 1 
        print("Current step Number = ",step[0])
        
        #MS create the closure, and then run the optimizer for each stream in sequence
        print("numStreams = ",numStreams)
        def closure():
            optimizerMS.zero_grad()
            style_score = 0
            content_score = 0
            for j in range(numStreams) :
        
            
                # correct the values of updated input image
                #if use01scale == True:
                    #input_param.data.clamp_(0, 1)

                #print("Current stream Number in closure() = ",j)
#                 optimizerMS.zero_grad()
                modelMS[j](input_param)
                

                if boundopt == True:
                    bound.zero_grad()
                    reg = bound(input_param)
                    if not torch.equal(reg.data,torch.cuda.FloatTensor([0])):
                        reg.backward()

                for sl in style_lossesMS[j]:
                    #print(f'{progressive_proportion=}')
                    ####mapweight= map(step[0],progressive_proportion*num_steps*(1-(j+1)/numStreams))
                    ####style_score += mapweight*sl.backward() #call backward method to grab the loss
                    style_score += sl.backward() 
                    #print(f'map step={step[0]}, stream={j} = {mapweight}')
                
                #print("stylescore for run", step[0], " stream ",j ," is ",style_score)

                #for cl in content_losses:
                #    content_score += cl.backward()

                if boundopt == True:
                    total_loss = style_score + reg  #+ content_score
                else:
                    total_loss = style_score

                #step[0] += 1

                if step[0] % 10 == 0:
                    #print("reg", reg)
                    #print(torch.max(input_param.data),torch.min(input_param.data))

                    print(f"step: {step}, model[{j}]")
                    print('-----------Style Loss : {:4f}'.format(
                        #style_score.data[0]))
                        style_score.data))
                    plt.plot(step[0],style_score.data.cpu(),'bo')
                    if boundopt == True:
                        print('Bound Loss : {:4f}'.format(
                           #reg.data[0]))
                            reg.data))
#                     print(torch.max(input_param.data),torch.min(input_param.data))
#                     print('Total Loss : {:4f}'.format(
#                         # total_loss.data[0]))
#                         total_loss.data))
#                     plt.figure()
#                     plt.imshow(input_param.data.detach().cpu().numpy().squeeze(),origin='lower')
#                     plt.title("For step %d input_param.data is "%variation[0])
#                     plt.show()

            return total_loss/numStreams   #return value for closer()

            # The update to an image happens in here:
        optimizerMS.step(closure)  #optimizer.step will call closure with its closure vars; #executes 20 iterations in this one line
                
          
        # END MS loop
        
        
        
    # a last correction...
    #if use01scale == True:
        #input_param.data.clamp_(0, 1)
    plt.show()
    return input_param.data   # Can return any of the MS input_params - they all refer to the same object

# %% [markdown]
# <div style="background-color: #AAFFAA">
# <h4> Finally, run the algorithm  </h4>
# </div>

# %%
# cell:RUN 

outputs = []
i = 0
while i < variations:
    
    print(f'{input_imgs[i].shape=}')
    output = run_style_transfer(cnnlist, style_img, input_imgs[i])


    plt.figure().set_size_inches(20, 20)
    out = imshow(output, N_FREQ, int(N_FRAMES*SYNTHETIC_LENGTH_FACTOR),title='Output Image')
    outputs.append(out)
    i += 1

# sphinx_gallery_thumbnail_number = 4
#figure(figsize=(8, 6), dpi=80)
plt.show()
# Out:
# input_imgs[i].shape=torch.Size([1, 257, 1, 867])
# run_style_transfer: cnnlist is [style_net(
#   (layers): Sequential(
#     (conv1): Conv2d(257, 512, kernel_size=(1, 2), stride=(1, 1), padding=valid, bias=False, padding_mode=circular)
#     (relu1): ReLU()
#   )
# ), style_net(
#   (layers): Sequential(
#     (conv1): Conv2d(257, 512, kernel_size=(1, 4), stride=(1, 1), padding=valid, bias=False, padding_mode=circular)
#     (relu1): ReLU()
#   )
# ), style_net(
#   (layers): Sequential(
#     (conv1): Conv2d(257, 512, kernel_size=(1, 8), stride=(1, 1), padding=valid, bias=False, padding_mode=circular)
#     (relu1): ReLU()
#   )
# ), style_net(
#   (layers): Sequential(
#     (conv1): Conv2d(257, 512, kernel_size=(1, 16), stride=(1, 1), padding=valid, bias=False, padding_mode=circular)
#     (relu1): ReLU()
#   )
# ), style_net(
#   (layers): Sequential(
#     (conv1): Conv2d(257, 512, kernel_size=(1, 32), stride=(1, 1), padding=valid, bias=False, padding_mode=circular)
#     (relu1): ReLU()
#   )
# ), style_net(
#   (layers): Sequential(
#     (conv1): Conv2d(257, 512, kernel_size=(1, 64), stride=(1, 1), padding=valid, bias=False, padding_mode=circular)
#     (relu1): ReLU()
#   )
# )]
# Building the style transfer model..
# CREATING, style_lossesMS is [[StyleLoss(
#   (gram): GramMatrix()
#   (criterion): MSELoss()
# )], None, None, None, None, None]
# Input range: tensor(0.0467, device='cuda:0') tensor(-0.0428, device='cuda:0')
# Sequential(
#   (conv_1): Conv2d(257, 512, kernel_size=(1, 2), stride=(1, 1), padding=valid, bias=False, padding_mode=circular)
#   (relu_1): ReLU()
#   (style_loss_1): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
# )
# Optimizing..
# Building the style transfer model..
# CREATING, style_lossesMS is [[StyleLoss(
#   (gram): GramMatrix()
#   (criterion): MSELoss()
# )], [StyleLoss(
#   (gram): GramMatrix()
#   (criterion): MSELoss()
# )], None, None, None, None]
# Input range: tensor(0.0467, device='cuda:0') tensor(-0.0428, device='cuda:0')
# Sequential(
#   (conv_1): Conv2d(257, 512, kernel_size=(1, 4), stride=(1, 1), padding=valid, bias=False, padding_mode=circular)
#   (relu_1): ReLU()
#   (style_loss_1): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
# )
# Optimizing..
# Building the style transfer model..
# CREATING, style_lossesMS is [[StyleLoss(
#   (gram): GramMatrix()
#   (criterion): MSELoss()
# )], [StyleLoss(
#   (gram): GramMatrix()
#   (criterion): MSELoss()
# )], [StyleLoss(
#   (gram): GramMatrix()
#   (criterion): MSELoss()
# )], None, None, None]
# Input range: tensor(0.0467, device='cuda:0') tensor(-0.0428, device='cuda:0')
# Sequential(
#   (conv_1): Conv2d(257, 512, kernel_size=(1, 8), stride=(1, 1), padding=valid, bias=False, padding_mode=circular)
#   (relu_1): ReLU()
#   (style_loss_1): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
# )
# Optimizing..
# Building the style transfer model..
# CREATING, style_lossesMS is [[StyleLoss(
#   (gram): GramMatrix()
#   (criterion): MSELoss()
# )], [StyleLoss(
#   (gram): GramMatrix()
#   (criterion): MSELoss()
# )], [StyleLoss(
#   (gram): GramMatrix()
#   (criterion): MSELoss()
# )], [StyleLoss(
#   (gram): GramMatrix()
#   (criterion): MSELoss()
# )], None, None]
# Input range: tensor(0.0467, device='cuda:0') tensor(-0.0428, device='cuda:0')
# Sequential(
#   (conv_1): Conv2d(257, 512, kernel_size=(1, 16), stride=(1, 1), padding=valid, bias=False, padding_mode=circular)
#   (relu_1): ReLU()
#   (style_loss_1): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
# )
# Optimizing..
# Building the style transfer model..
# CREATING, style_lossesMS is [[StyleLoss(
#   (gram): GramMatrix()
#   (criterion): MSELoss()
# )], [StyleLoss(
#   (gram): GramMatrix()
#   (criterion): MSELoss()
# )], [StyleLoss(
#   (gram): GramMatrix()
#   (criterion): MSELoss()
# )], [StyleLoss(
#   (gram): GramMatrix()
#   (criterion): MSELoss()
# )], [StyleLoss(
#   (gram): GramMatrix()
#   (criterion): MSELoss()
# )], None]
# Input range: tensor(0.0467, device='cuda:0') tensor(-0.0428, device='cuda:0')
# Sequential(
#   (conv_1): Conv2d(257, 512, kernel_size=(1, 32), stride=(1, 1), padding=valid, bias=False, padding_mode=circular)
#   (relu_1): ReLU()
#   (style_loss_1): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
# )
# Optimizing..
# Building the style transfer model..
# CREATING, style_lossesMS is [[StyleLoss(
#   (gram): GramMatrix()
#   (criterion): MSELoss()
# )], [StyleLoss(
#   (gram): GramMatrix()
#   (criterion): MSELoss()
# )], [StyleLoss(
#   (gram): GramMatrix()
#   (criterion): MSELoss()
# )], [StyleLoss(
#   (gram): GramMatrix()
#   (criterion): MSELoss()
# )], [StyleLoss(
#   (gram): GramMatrix()
#   (criterion): MSELoss()
# )], [StyleLoss(
#   (gram): GramMatrix()
#   (criterion): MSELoss()
# )]]
# Input range: tensor(0.0467, device='cuda:0') tensor(-0.0428, device='cuda:0')
# Sequential(
#   (conv_1): Conv2d(257, 512, kernel_size=(1, 64), stride=(1, 1), padding=valid, bias=False, padding_mode=circular)
#   (relu_1): ReLU()
#   (style_loss_1): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
# )
# Optimizing..
# Created 5 MS models
# Current step Number =  1
# numStreams =  6
# Current step Number =  2
# numStreams =  6
# Current step Number =  3
# numStreams =  6
# Current step Number =  4
# numStreams =  6
# Current step Number =  5
# numStreams =  6
# Current step Number =  6
# numStreams =  6
# Current step Number =  7
# numStreams =  6
# Current step Number =  8
# numStreams =  6
# Current step Number =  9
# numStreams =  6
# Current step Number =  10
# numStreams =  6
# step: [10], model[0]
# -----------Style Loss : 0.008580
# step: [10], model[1]
# -----------Style Loss : 0.016282
# step: [10], model[2]
# -----------Style Loss : 0.022733
# step: [10], model[3]
# -----------Style Loss : 0.028533
# step: [10], model[4]
# -----------Style Loss : 0.035937
# step: [10], model[5]
# -----------Style Loss : 0.048354
# step: [10], model[0]
# -----------Style Loss : 0.008464
# step: [10], model[1]
# -----------Style Loss : 0.016068
# step: [10], model[2]
# -----------Style Loss : 0.022426
# step: [10], model[3]
# -----------Style Loss : 0.028159
# step: [10], model[4]
# -----------Style Loss : 0.035485
# step: [10], model[5]
# -----------Style Loss : 0.047791
# step: [10], model[0]
# -----------Style Loss : 0.008367
# step: [10], model[1]
# -----------Style Loss : 0.015861
# step: [10], model[2]
# -----------Style Loss : 0.022119
# step: [10], model[3]
# -----------Style Loss : 0.027773
# step: [10], model[4]
# -----------Style Loss : 0.035012
# step: [10], model[5]
# -----------Style Loss : 0.047200
# step: [10], model[0]
# -----------Style Loss : 0.008261
# step: [10], model[1]
# -----------Style Loss : 0.015686
# step: [10], model[2]
# -----------Style Loss : 0.021877
# step: [10], model[3]
# -----------Style Loss : 0.027460
# step: [10], model[4]
# -----------Style Loss : 0.034612
# step: [10], model[5]
# -----------Style Loss : 0.046657
# step: [10], model[0]
# -----------Style Loss : 0.008145
# step: [10], model[1]
# -----------Style Loss : 0.015471
# step: [10], model[2]
# -----------Style Loss : 0.021585
# step: [10], model[3]
# -----------Style Loss : 0.027098
# step: [10], model[4]
# -----------Style Loss : 0.034185
# step: [10], model[5]
# -----------Style Loss : 0.046137
# step: [10], model[0]
# -----------Style Loss : 0.008033
# step: [10], model[1]
# -----------Style Loss : 0.015250
# step: [10], model[2]
# -----------Style Loss : 0.021295
# step: [10], model[3]
# -----------Style Loss : 0.026735
# step: [10], model[4]
# -----------Style Loss : 0.033738
# step: [10], model[5]
# -----------Style Loss : 0.045549
# step: [10], model[0]
# -----------Style Loss : 0.007957
# step: [10], model[1]
# -----------Style Loss : 0.015096
# step: [10], model[2]
# -----------Style Loss : 0.021086
# step: [10], model[3]
# -----------Style Loss : 0.026473
# step: [10], model[4]
# -----------Style Loss : 0.033409
# step: [10], model[5]
# -----------Style Loss : 0.045120
# step: [10], model[0]
# -----------Style Loss : 0.007844
# step: [10], model[1]
# -----------Style Loss : 0.014881
# step: [10], model[2]
# -----------Style Loss : 0.020807
# step: [10], model[3]
# -----------Style Loss : 0.026136
# step: [10], model[4]
# -----------Style Loss : 0.033013
# step: [10], model[5]
# -----------Style Loss : 0.044623
# step: [10], model[0]
# -----------Style Loss : 0.007719
# step: [10], model[1]
# -----------Style Loss : 0.014654
# step: [10], model[2]
# -----------Style Loss : 0.020505
# step: [10], model[3]
# -----------Style Loss : 0.025765
# step: [10], model[4]
# -----------Style Loss : 0.032556
# step: [10], model[5]
# -----------Style Loss : 0.044012
# step: [10], model[0]
# -----------Style Loss : 0.007653
# step: [10], model[1]
# -----------Style Loss : 0.014499
# step: [10], model[2]
# -----------Style Loss : 0.020276
# step: [10], model[3]
# -----------Style Loss : 0.025488
# step: [10], model[4]
# -----------Style Loss : 0.032222
# step: [10], model[5]
# -----------Style Loss : 0.043606
# step: [10], model[0]
# -----------Style Loss : 0.007585
# step: [10], model[1]
# -----------Style Loss : 0.014374
# step: [10], model[2]
# -----------Style Loss : 0.020100
# step: [10], model[3]
# -----------Style Loss : 0.025257
# step: [10], model[4]
# -----------Style Loss : 0.031937
# step: [10], model[5]
# -----------Style Loss : 0.043236
# step: [10], model[0]
# -----------Style Loss : 0.007477
# step: [10], model[1]
# -----------Style Loss : 0.014157
# step: [10], model[2]
# -----------Style Loss : 0.019788
# step: [10], model[3]
# -----------Style Loss : 0.024880
# step: [10], model[4]
# -----------Style Loss : 0.031498
# step: [10], model[5]
# -----------Style Loss : 0.042706
# step: [10], model[0]
# -----------Style Loss : 0.007488
# step: [10], model[1]
# -----------Style Loss : 0.014184
# step: [10], model[2]
# -----------Style Loss : 0.019828
# step: [10], model[3]
# -----------Style Loss : 0.024900
# step: [10], model[4]
# -----------Style Loss : 0.031464
# step: [10], model[5]
# -----------Style Loss : 0.042499
# step: [10], model[0]
# -----------Style Loss : 0.007384
# step: [10], model[1]
# -----------Style Loss : 0.013991
# step: [10], model[2]
# -----------Style Loss : 0.019549
# step: [10], model[3]
# -----------Style Loss : 0.024568
# step: [10], model[4]
# -----------Style Loss : 0.031088
# step: [10], model[5]
# -----------Style Loss : 0.042115
# step: [10], model[0]
# -----------Style Loss : 0.007287
# step: [10], model[1]
# -----------Style Loss : 0.013816
# step: [10], model[2]
# -----------Style Loss : 0.019309
# step: [10], model[3]
# -----------Style Loss : 0.024281
# step: [10], model[4]
# -----------Style Loss : 0.030761
# step: [10], model[5]
# -----------Style Loss : 0.041742
# step: [10], model[0]
# -----------Style Loss : 0.007191
# step: [10], model[1]
# -----------Style Loss : 0.013642
# step: [10], model[2]
# -----------Style Loss : 0.019076
# step: [10], model[3]
# -----------Style Loss : 0.023998
# step: [10], model[4]
# -----------Style Loss : 0.030425
# step: [10], model[5]
# -----------Style Loss : 0.041301
# step: [10], model[0]
# -----------Style Loss : 0.007162
# step: [10], model[1]
# -----------Style Loss : 0.013563
# step: [10], model[2]
# -----------Style Loss : 0.018968
# step: [10], model[3]
# -----------Style Loss : 0.023859
# step: [10], model[4]
# -----------Style Loss : 0.030240
# step: [10], model[5]
# -----------Style Loss : 0.040985
# step: [10], model[0]
# -----------Style Loss : 0.007052
# step: [10], model[1]
# -----------Style Loss : 0.013393
# step: [10], model[2]
# -----------Style Loss : 0.018745
# step: [10], model[3]
# -----------Style Loss : 0.023588
# step: [10], model[4]
# -----------Style Loss : 0.029923
# step: [10], model[5]
# -----------Style Loss : 0.040609
# step: [10], model[0]
# -----------Style Loss : 0.006995
# step: [10], model[1]
# -----------Style Loss : 0.013286
# step: [10], model[2]
# -----------Style Loss : 0.018581
# step: [10], model[3]
# -----------Style Loss : 0.023363
# step: [10], model[4]
# -----------Style Loss : 0.029630
# step: [10], model[5]
# -----------Style Loss : 0.040234
# step: [10], model[0]
# -----------Style Loss : 0.006947
# step: [10], model[1]
# -----------Style Loss : 0.013195
# step: [10], model[2]
# -----------Style Loss : 0.018446
# step: [10], model[3]
# -----------Style Loss : 0.023180
# step: [10], model[4]
# -----------Style Loss : 0.029391
# step: [10], model[5]
# -----------Style Loss : 0.039917
# Current step Number =  11
# numStreams =  6
# Current step Number =  12
# numStreams =  6
# Current step Number =  13
# numStreams =  6
# Current step Number =  14
# numStreams =  6
# Current step Number =  15
# numStreams =  6
# Current step Number =  16
# numStreams =  6
# Current step Number =  17
# numStreams =  6
# Current step Number =  18
# numStreams =  6
# Current step Number =  19
# numStreams =  6
# Current step Number =  20
# numStreams =  6
# step: [20], model[0]
# -----------Style Loss : 0.003175
# step: [20], model[1]
# -----------Style Loss : 0.006023
# step: [20], model[2]
# -----------Style Loss : 0.008427
# step: [20], model[3]
# -----------Style Loss : 0.010552
# step: [20], model[4]
# -----------Style Loss : 0.013461
# step: [20], model[5]
# -----------Style Loss : 0.018135
# step: [20], model[0]
# -----------Style Loss : 0.003171
# step: [20], model[1]
# -----------Style Loss : 0.006014
# step: [20], model[2]
# -----------Style Loss : 0.008415
# step: [20], model[3]
# -----------Style Loss : 0.010536
# step: [20], model[4]
# -----------Style Loss : 0.013437
# step: [20], model[5]
# -----------Style Loss : 0.018094
# step: [20], model[0]
# -----------Style Loss : 0.003163
# step: [20], model[1]
# -----------Style Loss : 0.006002
# step: [20], model[2]
# -----------Style Loss : 0.008397
# step: [20], model[3]
# -----------Style Loss : 0.010513
# step: [20], model[4]
# -----------Style Loss : 0.013408
# step: [20], model[5]
# -----------Style Loss : 0.018054
# step: [20], model[0]
# -----------Style Loss : 0.003156
# step: [20], model[1]
# -----------Style Loss : 0.005989
# step: [20], model[2]
# -----------Style Loss : 0.008379
# step: [20], model[3]
# -----------Style Loss : 0.010491
# step: [20], model[4]
# -----------Style Loss : 0.013378
# step: [20], model[5]
# -----------Style Loss : 0.018010
# step: [20], model[0]
# -----------Style Loss : 0.003148
# step: [20], model[1]
# -----------Style Loss : 0.005976
# step: [20], model[2]
# -----------Style Loss : 0.008361
# step: [20], model[3]
# -----------Style Loss : 0.010468
# step: [20], model[4]
# -----------Style Loss : 0.013351
# step: [20], model[5]
# -----------Style Loss : 0.017970
# step: [20], model[0]
# -----------Style Loss : 0.003141
# step: [20], model[1]
# -----------Style Loss : 0.005963
# step: [20], model[2]
# -----------Style Loss : 0.008343
# step: [20], model[3]
# -----------Style Loss : 0.010445
# step: [20], model[4]
# -----------Style Loss : 0.013321
# step: [20], model[5]
# -----------Style Loss : 0.017927
# step: [20], model[0]
# -----------Style Loss : 0.003135
# step: [20], model[1]
# -----------Style Loss : 0.005951
# step: [20], model[2]
# -----------Style Loss : 0.008325
# step: [20], model[3]
# -----------Style Loss : 0.010423
# step: [20], model[4]
# -----------Style Loss : 0.013293
# step: [20], model[5]
# -----------Style Loss : 0.017886
# step: [20], model[0]
# -----------Style Loss : 0.003129
# step: [20], model[1]
# -----------Style Loss : 0.005939
# step: [20], model[2]
# -----------Style Loss : 0.008310
# step: [20], model[3]
# -----------Style Loss : 0.010405
# step: [20], model[4]
# -----------Style Loss : 0.013269
# step: [20], model[5]
# -----------Style Loss : 0.017847
# step: [20], model[0]
# -----------Style Loss : 0.003122
# step: [20], model[1]
# -----------Style Loss : 0.005927
# step: [20], model[2]
# -----------Style Loss : 0.008291
# step: [20], model[3]
# -----------Style Loss : 0.010381
# step: [20], model[4]
# -----------Style Loss : 0.013239
# step: [20], model[5]
# -----------Style Loss : 0.017807
# step: [20], model[0]
# -----------Style Loss : 0.003117
# step: [20], model[1]
# -----------Style Loss : 0.005916
# step: [20], model[2]
# -----------Style Loss : 0.008275
# step: [20], model[3]
# -----------Style Loss : 0.010361
# step: [20], model[4]
# -----------Style Loss : 0.013212
# step: [20], model[5]
# -----------Style Loss : 0.017768
# step: [20], model[0]
# -----------Style Loss : 0.003114
# step: [20], model[1]
# -----------Style Loss : 0.005911
# step: [20], model[2]
# -----------Style Loss : 0.008267
# step: [20], model[3]
# -----------Style Loss : 0.010351
# step: [20], model[4]
# -----------Style Loss : 0.013193
# step: [20], model[5]
# -----------Style Loss : 0.017732
# step: [20], model[0]
# -----------Style Loss : 0.003106
# step: [20], model[1]
# -----------Style Loss : 0.005897
# step: [20], model[2]
# -----------Style Loss : 0.008247
# step: [20], model[3]
# -----------Style Loss : 0.010327
# step: [20], model[4]
# -----------Style Loss : 0.013162
# step: [20], model[5]
# -----------Style Loss : 0.017695
# step: [20], model[0]
# -----------Style Loss : 0.003102
# step: [20], model[1]
# -----------Style Loss : 0.005890
# step: [20], model[2]
# -----------Style Loss : 0.008239
# step: [20], model[3]
# -----------Style Loss : 0.010315
# step: [20], model[4]
# -----------Style Loss : 0.013141
# step: [20], model[5]
# -----------Style Loss : 0.017654
# step: [20], model[0]
# -----------Style Loss : 0.003095
# step: [20], model[1]
# -----------Style Loss : 0.005877
# step: [20], model[2]
# -----------Style Loss : 0.008219
# step: [20], model[3]
# -----------Style Loss : 0.010290
# step: [20], model[4]
# -----------Style Loss : 0.013111
# step: [20], model[5]
# -----------Style Loss : 0.017618
# step: [20], model[0]
# -----------Style Loss : 0.003093
# step: [20], model[1]
# -----------Style Loss : 0.005874
# step: [20], model[2]
# -----------Style Loss : 0.008213
# step: [20], model[3]
# -----------Style Loss : 0.010280
# step: [20], model[4]
# -----------Style Loss : 0.013093
# step: [20], model[5]
# -----------Style Loss : 0.017582
# step: [20], model[0]
# -----------Style Loss : 0.003085
# step: [20], model[1]
# -----------Style Loss : 0.005856
# step: [20], model[2]
# -----------Style Loss : 0.008188
# step: [20], model[3]
# -----------Style Loss : 0.010252
# step: [20], model[4]
# -----------Style Loss : 0.013060
# step: [20], model[5]
# -----------Style Loss : 0.017545
# step: [20], model[0]
# -----------Style Loss : 0.003079
# step: [20], model[1]
# -----------Style Loss : 0.005847
# step: [20], model[2]
# -----------Style Loss : 0.008176
# step: [20], model[3]
# -----------Style Loss : 0.010236
# step: [20], model[4]
# -----------Style Loss : 0.013039
# step: [20], model[5]
# -----------Style Loss : 0.017509
# step: [20], model[0]
# -----------Style Loss : 0.003074
# step: [20], model[1]
# -----------Style Loss : 0.005836
# step: [20], model[2]
# -----------Style Loss : 0.008161
# step: [20], model[3]
# -----------Style Loss : 0.010216
# step: [20], model[4]
# -----------Style Loss : 0.013013
# step: [20], model[5]
# -----------Style Loss : 0.017469
# step: [20], model[0]
# -----------Style Loss : 0.003068
# step: [20], model[1]
# -----------Style Loss : 0.005826
# step: [20], model[2]
# -----------Style Loss : 0.008146
# step: [20], model[3]
# -----------Style Loss : 0.010197
# step: [20], model[4]
# -----------Style Loss : 0.012987
# step: [20], model[5]
# -----------Style Loss : 0.017432
# step: [20], model[0]
# -----------Style Loss : 0.003063
# step: [20], model[1]
# -----------Style Loss : 0.005815
# step: [20], model[2]
# -----------Style Loss : 0.008130
# step: [20], model[3]
# -----------Style Loss : 0.010176
# step: [20], model[4]
# -----------Style Loss : 0.012961
# step: [20], model[5]
# -----------Style Loss : 0.017397
# Current step Number =  21
# numStreams =  6
# Current step Number =  22
# numStreams =  6
# Current step Number =  23
# numStreams =  6
# Current step Number =  24
# numStreams =  6
# Current step Number =  25
# numStreams =  6
# Current step Number =  26
# numStreams =  6
# Current step Number =  27
# numStreams =  6
# Current step Number =  28
# numStreams =  6
# Current step Number =  29
# numStreams =  6
# Current step Number =  30
# numStreams =  6
# step: [30], model[0]
# -----------Style Loss : 0.002430
# step: [30], model[1]
# -----------Style Loss : 0.004628
# step: [30], model[2]
# -----------Style Loss : 0.006460
# step: [30], model[3]
# -----------Style Loss : 0.008064
# step: [30], model[4]
# -----------Style Loss : 0.010196
# step: [30], model[5]
# -----------Style Loss : 0.013450
# step: [30], model[0]
# -----------Style Loss : 0.002429
# step: [30], model[1]
# -----------Style Loss : 0.004625
# step: [30], model[2]
# -----------Style Loss : 0.006455
# step: [30], model[3]
# -----------Style Loss : 0.008057
# step: [30], model[4]
# -----------Style Loss : 0.010187
# step: [30], model[5]
# -----------Style Loss : 0.013438
# step: [30], model[0]
# -----------Style Loss : 0.002426
# step: [30], model[1]
# -----------Style Loss : 0.004620
# step: [30], model[2]
# -----------Style Loss : 0.006448
# step: [30], model[3]
# -----------Style Loss : 0.008049
# step: [30], model[4]
# -----------Style Loss : 0.010178
# step: [30], model[5]
# -----------Style Loss : 0.013425
# step: [30], model[0]
# -----------Style Loss : 0.002423
# step: [30], model[1]
# -----------Style Loss : 0.004614
# step: [30], model[2]
# -----------Style Loss : 0.006441
# step: [30], model[3]
# -----------Style Loss : 0.008039
# step: [30], model[4]
# -----------Style Loss : 0.010166
# step: [30], model[5]
# -----------Style Loss : 0.013411
# step: [30], model[0]
# -----------Style Loss : 0.002420
# step: [30], model[1]
# -----------Style Loss : 0.004611
# step: [30], model[2]
# -----------Style Loss : 0.006437
# step: [30], model[3]
# -----------Style Loss : 0.008034
# step: [30], model[4]
# -----------Style Loss : 0.010159
# step: [30], model[5]
# -----------Style Loss : 0.013398
# step: [30], model[0]
# -----------Style Loss : 0.002417
# step: [30], model[1]
# -----------Style Loss : 0.004604
# step: [30], model[2]
# -----------Style Loss : 0.006427
# step: [30], model[3]
# -----------Style Loss : 0.008023
# step: [30], model[4]
# -----------Style Loss : 0.010146
# step: [30], model[5]
# -----------Style Loss : 0.013386
# step: [30], model[0]
# -----------Style Loss : 0.002416
# step: [30], model[1]
# -----------Style Loss : 0.004603
# step: [30], model[2]
# -----------Style Loss : 0.006424
# step: [30], model[3]
# -----------Style Loss : 0.008020
# step: [30], model[4]
# -----------Style Loss : 0.010140
# step: [30], model[5]
# -----------Style Loss : 0.013375
# step: [30], model[0]
# -----------Style Loss : 0.002414
# step: [30], model[1]
# -----------Style Loss : 0.004599
# step: [30], model[2]
# -----------Style Loss : 0.006419
# step: [30], model[3]
# -----------Style Loss : 0.008013
# step: [30], model[4]
# -----------Style Loss : 0.010131
# step: [30], model[5]
# -----------Style Loss : 0.013364
# step: [30], model[0]
# -----------Style Loss : 0.002411
# step: [30], model[1]
# -----------Style Loss : 0.004595
# step: [30], model[2]
# -----------Style Loss : 0.006413
# step: [30], model[3]
# -----------Style Loss : 0.008005
# step: [30], model[4]
# -----------Style Loss : 0.010122
# step: [30], model[5]
# -----------Style Loss : 0.013352
# step: [30], model[0]
# -----------Style Loss : 0.002410
# step: [30], model[1]
# -----------Style Loss : 0.004592
# step: [30], model[2]
# -----------Style Loss : 0.006410
# step: [30], model[3]
# -----------Style Loss : 0.008000
# step: [30], model[4]
# -----------Style Loss : 0.010114
# step: [30], model[5]
# -----------Style Loss : 0.013339
# step: [30], model[0]
# -----------Style Loss : 0.002407
# step: [30], model[1]
# -----------Style Loss : 0.004587
# step: [30], model[2]
# -----------Style Loss : 0.006403
# step: [30], model[3]
# -----------Style Loss : 0.007992
# step: [30], model[4]
# -----------Style Loss : 0.010104
# step: [30], model[5]
# -----------Style Loss : 0.013326
# step: [30], model[0]
# -----------Style Loss : 0.002407
# step: [30], model[1]
# -----------Style Loss : 0.004585
# step: [30], model[2]
# -----------Style Loss : 0.006400
# step: [30], model[3]
# -----------Style Loss : 0.007988
# step: [30], model[4]
# -----------Style Loss : 0.010097
# step: [30], model[5]
# -----------Style Loss : 0.013314
# step: [30], model[0]
# -----------Style Loss : 0.002404
# step: [30], model[1]
# -----------Style Loss : 0.004581
# step: [30], model[2]
# -----------Style Loss : 0.006395
# step: [30], model[3]
# -----------Style Loss : 0.007982
# step: [30], model[4]
# -----------Style Loss : 0.010089
# step: [30], model[5]
# -----------Style Loss : 0.013303
# step: [30], model[0]
# -----------Style Loss : 0.002401
# step: [30], model[1]
# -----------Style Loss : 0.004576
# step: [30], model[2]
# -----------Style Loss : 0.006387
# step: [30], model[3]
# -----------Style Loss : 0.007972
# step: [30], model[4]
# -----------Style Loss : 0.010078
# step: [30], model[5]
# -----------Style Loss : 0.013291
# step: [30], model[0]
# -----------Style Loss : 0.002399
# step: [30], model[1]
# -----------Style Loss : 0.004573
# step: [30], model[2]
# -----------Style Loss : 0.006382
# step: [30], model[3]
# -----------Style Loss : 0.007966
# step: [30], model[4]
# -----------Style Loss : 0.010070
# step: [30], model[5]
# -----------Style Loss : 0.013280
# step: [30], model[0]
# -----------Style Loss : 0.002397
# step: [30], model[1]
# -----------Style Loss : 0.004568
# step: [30], model[2]
# -----------Style Loss : 0.006376
# step: [30], model[3]
# -----------Style Loss : 0.007959
# step: [30], model[4]
# -----------Style Loss : 0.010061
# step: [30], model[5]
# -----------Style Loss : 0.013267
# step: [30], model[0]
# -----------Style Loss : 0.002394
# step: [30], model[1]
# -----------Style Loss : 0.004564
# step: [30], model[2]
# -----------Style Loss : 0.006369
# step: [30], model[3]
# -----------Style Loss : 0.007950
# step: [30], model[4]
# -----------Style Loss : 0.010050
# step: [30], model[5]
# -----------Style Loss : 0.013254
# step: [30], model[0]
# -----------Style Loss : 0.002393
# step: [30], model[1]
# -----------Style Loss : 0.004561
# step: [30], model[2]
# -----------Style Loss : 0.006366
# step: [30], model[3]
# -----------Style Loss : 0.007945
# step: [30], model[4]
# -----------Style Loss : 0.010043
# step: [30], model[5]
# -----------Style Loss : 0.013243
# step: [30], model[0]
# -----------Style Loss : 0.002391
# step: [30], model[1]
# -----------Style Loss : 0.004556
# step: [30], model[2]
# -----------Style Loss : 0.006359
# step: [30], model[3]
# -----------Style Loss : 0.007937
# step: [30], model[4]
# -----------Style Loss : 0.010033
# step: [30], model[5]
# -----------Style Loss : 0.013230
# step: [30], model[0]
# -----------Style Loss : 0.002389
# step: [30], model[1]
# -----------Style Loss : 0.004553
# step: [30], model[2]
# -----------Style Loss : 0.006354
# step: [30], model[3]
# -----------Style Loss : 0.007931
# step: [30], model[4]
# -----------Style Loss : 0.010026
# step: [30], model[5]
# -----------Style Loss : 0.013218
# Current step Number =  31
# numStreams =  6
# Current step Number =  32
# numStreams =  6
# Current step Number =  33
# numStreams =  6
# Current step Number =  34
# numStreams =  6
# Current step Number =  35
# numStreams =  6
# Current step Number =  36
# numStreams =  6
# Current step Number =  37
# numStreams =  6
# Current step Number =  38
# numStreams =  6
# Current step Number =  39
# numStreams =  6
# Current step Number =  40
# numStreams =  6
# step: [40], model[0]
# -----------Style Loss : 0.002123
# step: [40], model[1]
# -----------Style Loss : 0.004050
# step: [40], model[2]
# -----------Style Loss : 0.005666
# step: [40], model[3]
# -----------Style Loss : 0.007077
# step: [40], model[4]
# -----------Style Loss : 0.008922
# step: [40], model[5]
# -----------Style Loss : 0.011740
# step: [40], model[0]
# -----------Style Loss : 0.002121
# step: [40], model[1]
# -----------Style Loss : 0.004047
# step: [40], model[2]
# -----------Style Loss : 0.005664
# step: [40], model[3]
# -----------Style Loss : 0.007074
# step: [40], model[4]
# -----------Style Loss : 0.008918
# step: [40], model[5]
# -----------Style Loss : 0.011735
# step: [40], model[0]
# -----------Style Loss : 0.002119
# step: [40], model[1]
# -----------Style Loss : 0.004044
# step: [40], model[2]
# -----------Style Loss : 0.005659
# step: [40], model[3]
# -----------Style Loss : 0.007069
# step: [40], model[4]
# -----------Style Loss : 0.008913
# step: [40], model[5]
# -----------Style Loss : 0.011728
# step: [40], model[0]
# -----------Style Loss : 0.002119
# step: [40], model[1]
# -----------Style Loss : 0.004044
# step: [40], model[2]
# -----------Style Loss : 0.005658
# step: [40], model[3]
# -----------Style Loss : 0.007067
# step: [40], model[4]
# -----------Style Loss : 0.008910
# step: [40], model[5]
# -----------Style Loss : 0.011723
# step: [40], model[0]
# -----------Style Loss : 0.002118
# step: [40], model[1]
# -----------Style Loss : 0.004042
# step: [40], model[2]
# -----------Style Loss : 0.005656
# step: [40], model[3]
# -----------Style Loss : 0.007064
# step: [40], model[4]
# -----------Style Loss : 0.008906
# step: [40], model[5]
# -----------Style Loss : 0.011718
# step: [40], model[0]
# -----------Style Loss : 0.002118
# step: [40], model[1]
# -----------Style Loss : 0.004041
# step: [40], model[2]
# -----------Style Loss : 0.005654
# step: [40], model[3]
# -----------Style Loss : 0.007061
# step: [40], model[4]
# -----------Style Loss : 0.008902
# step: [40], model[5]
# -----------Style Loss : 0.011713
# step: [40], model[0]
# -----------Style Loss : 0.002117
# step: [40], model[1]
# -----------Style Loss : 0.004039
# step: [40], model[2]
# -----------Style Loss : 0.005651
# step: [40], model[3]
# -----------Style Loss : 0.007057
# step: [40], model[4]
# -----------Style Loss : 0.008897
# step: [40], model[5]
# -----------Style Loss : 0.011706
# step: [40], model[0]
# -----------Style Loss : 0.002117
# step: [40], model[1]
# -----------Style Loss : 0.004038
# step: [40], model[2]
# -----------Style Loss : 0.005649
# step: [40], model[3]
# -----------Style Loss : 0.007055
# step: [40], model[4]
# -----------Style Loss : 0.008894
# step: [40], model[5]
# -----------Style Loss : 0.011702
# step: [40], model[0]
# -----------Style Loss : 0.002115
# step: [40], model[1]
# -----------Style Loss : 0.004035
# step: [40], model[2]
# -----------Style Loss : 0.005646
# step: [40], model[3]
# -----------Style Loss : 0.007052
# step: [40], model[4]
# -----------Style Loss : 0.008890
# step: [40], model[5]
# -----------Style Loss : 0.011697
# step: [40], model[0]
# -----------Style Loss : 0.002115
# step: [40], model[1]
# -----------Style Loss : 0.004033
# step: [40], model[2]
# -----------Style Loss : 0.005644
# step: [40], model[3]
# -----------Style Loss : 0.007048
# step: [40], model[4]
# -----------Style Loss : 0.008886
# step: [40], model[5]
# -----------Style Loss : 0.011691
# step: [40], model[0]
# -----------Style Loss : 0.002115
# step: [40], model[1]
# -----------Style Loss : 0.004032
# step: [40], model[2]
# -----------Style Loss : 0.005643
# step: [40], model[3]
# -----------Style Loss : 0.007047
# step: [40], model[4]
# -----------Style Loss : 0.008883
# step: [40], model[5]
# -----------Style Loss : 0.011686
# step: [40], model[0]
# -----------Style Loss : 0.002114
# step: [40], model[1]
# -----------Style Loss : 0.004031
# step: [40], model[2]
# -----------Style Loss : 0.005640
# step: [40], model[3]
# -----------Style Loss : 0.007044
# step: [40], model[4]
# -----------Style Loss : 0.008879
# step: [40], model[5]
# -----------Style Loss : 0.011681
# step: [40], model[0]
# -----------Style Loss : 0.002113
# step: [40], model[1]
# -----------Style Loss : 0.004029
# step: [40], model[2]
# -----------Style Loss : 0.005638
# step: [40], model[3]
# -----------Style Loss : 0.007041
# step: [40], model[4]
# -----------Style Loss : 0.008875
# step: [40], model[5]
# -----------Style Loss : 0.011676
# step: [40], model[0]
# -----------Style Loss : 0.002111
# step: [40], model[1]
# -----------Style Loss : 0.004027
# step: [40], model[2]
# -----------Style Loss : 0.005635
# step: [40], model[3]
# -----------Style Loss : 0.007037
# step: [40], model[4]
# -----------Style Loss : 0.008871
# step: [40], model[5]
# -----------Style Loss : 0.011671
# step: [40], model[0]
# -----------Style Loss : 0.002110
# step: [40], model[1]
# -----------Style Loss : 0.004026
# step: [40], model[2]
# -----------Style Loss : 0.005633
# step: [40], model[3]
# -----------Style Loss : 0.007035
# step: [40], model[4]
# -----------Style Loss : 0.008867
# step: [40], model[5]
# -----------Style Loss : 0.011665
# step: [40], model[0]
# -----------Style Loss : 0.002109
# step: [40], model[1]
# -----------Style Loss : 0.004023
# step: [40], model[2]
# -----------Style Loss : 0.005631
# step: [40], model[3]
# -----------Style Loss : 0.007031
# step: [40], model[4]
# -----------Style Loss : 0.008863
# step: [40], model[5]
# -----------Style Loss : 0.011659
# step: [40], model[0]
# -----------Style Loss : 0.002108
# step: [40], model[1]
# -----------Style Loss : 0.004021
# step: [40], model[2]
# -----------Style Loss : 0.005628
# step: [40], model[3]
# -----------Style Loss : 0.007028
# step: [40], model[4]
# -----------Style Loss : 0.008859
# step: [40], model[5]
# -----------Style Loss : 0.011654
# step: [40], model[0]
# -----------Style Loss : 0.002108
# step: [40], model[1]
# -----------Style Loss : 0.004020
# step: [40], model[2]
# -----------Style Loss : 0.005626
# step: [40], model[3]
# -----------Style Loss : 0.007026
# step: [40], model[4]
# -----------Style Loss : 0.008856
# step: [40], model[5]
# -----------Style Loss : 0.011649
# step: [40], model[0]
# -----------Style Loss : 0.002107
# step: [40], model[1]
# -----------Style Loss : 0.004017
# step: [40], model[2]
# -----------Style Loss : 0.005623
# step: [40], model[3]
# -----------Style Loss : 0.007022
# step: [40], model[4]
# -----------Style Loss : 0.008851
# step: [40], model[5]
# -----------Style Loss : 0.011644
# step: [40], model[0]
# -----------Style Loss : 0.002106
# step: [40], model[1]
# -----------Style Loss : 0.004016
# step: [40], model[2]
# -----------Style Loss : 0.005621
# step: [40], model[3]
# -----------Style Loss : 0.007019
# step: [40], model[4]
# -----------Style Loss : 0.008847
# step: [40], model[5]
# -----------Style Loss : 0.011638
# Current step Number =  41
# numStreams =  6
# Current step Number =  42
# numStreams =  6
# Current step Number =  43
# numStreams =  6
# Current step Number =  44
# numStreams =  6
# Current step Number =  45
# numStreams =  6
# Current step Number =  46
# numStreams =  6
# Current step Number =  47
# numStreams =  6
# Current step Number =  48
# numStreams =  6
# Current step Number =  49
# numStreams =  6
# Current step Number =  50
# numStreams =  6
# step: [50], model[0]
# -----------Style Loss : 0.001949
# step: [50], model[1]
# -----------Style Loss : 0.003703
# step: [50], model[2]
# -----------Style Loss : 0.005199
# step: [50], model[3]
# -----------Style Loss : 0.006500
# step: [50], model[4]
# -----------Style Loss : 0.008176
# step: [50], model[5]
# -----------Style Loss : 0.010758
# step: [50], model[0]
# -----------Style Loss : 0.001948
# step: [50], model[1]
# -----------Style Loss : 0.003701
# step: [50], model[2]
# -----------Style Loss : 0.005197
# step: [50], model[3]
# -----------Style Loss : 0.006497
# step: [50], model[4]
# -----------Style Loss : 0.008172
# step: [50], model[5]
# -----------Style Loss : 0.010753
# step: [50], model[0]
# -----------Style Loss : 0.001948
# step: [50], model[1]
# -----------Style Loss : 0.003700
# step: [50], model[2]
# -----------Style Loss : 0.005194
# step: [50], model[3]
# -----------Style Loss : 0.006494
# step: [50], model[4]
# -----------Style Loss : 0.008169
# step: [50], model[5]
# -----------Style Loss : 0.010749
# step: [50], model[0]
# -----------Style Loss : 0.001947
# step: [50], model[1]
# -----------Style Loss : 0.003699
# step: [50], model[2]
# -----------Style Loss : 0.005192
# step: [50], model[3]
# -----------Style Loss : 0.006492
# step: [50], model[4]
# -----------Style Loss : 0.008166
# step: [50], model[5]
# -----------Style Loss : 0.010745
# step: [50], model[0]
# -----------Style Loss : 0.001946
# step: [50], model[1]
# -----------Style Loss : 0.003697
# step: [50], model[2]
# -----------Style Loss : 0.005190
# step: [50], model[3]
# -----------Style Loss : 0.006489
# step: [50], model[4]
# -----------Style Loss : 0.008162
# step: [50], model[5]
# -----------Style Loss : 0.010740
# step: [50], model[0]
# -----------Style Loss : 0.001945
# step: [50], model[1]
# -----------Style Loss : 0.003697
# step: [50], model[2]
# -----------Style Loss : 0.005190
# step: [50], model[3]
# -----------Style Loss : 0.006488
# step: [50], model[4]
# -----------Style Loss : 0.008161
# step: [50], model[5]
# -----------Style Loss : 0.010737
# step: [50], model[0]
# -----------Style Loss : 0.001945
# step: [50], model[1]
# -----------Style Loss : 0.003695
# step: [50], model[2]
# -----------Style Loss : 0.005187
# step: [50], model[3]
# -----------Style Loss : 0.006485
# step: [50], model[4]
# -----------Style Loss : 0.008157
# step: [50], model[5]
# -----------Style Loss : 0.010732
# step: [50], model[0]
# -----------Style Loss : 0.001944
# step: [50], model[1]
# -----------Style Loss : 0.003693
# step: [50], model[2]
# -----------Style Loss : 0.005185
# step: [50], model[3]
# -----------Style Loss : 0.006483
# step: [50], model[4]
# -----------Style Loss : 0.008154
# step: [50], model[5]
# -----------Style Loss : 0.010728
# step: [50], model[0]
# -----------Style Loss : 0.001943
# step: [50], model[1]
# -----------Style Loss : 0.003692
# step: [50], model[2]
# -----------Style Loss : 0.005183
# step: [50], model[3]
# -----------Style Loss : 0.006480
# step: [50], model[4]
# -----------Style Loss : 0.008150
# step: [50], model[5]
# -----------Style Loss : 0.010723
# step: [50], model[0]
# -----------Style Loss : 0.001943
# step: [50], model[1]
# -----------Style Loss : 0.003691
# step: [50], model[2]
# -----------Style Loss : 0.005181
# step: [50], model[3]
# -----------Style Loss : 0.006477
# step: [50], model[4]
# -----------Style Loss : 0.008147
# step: [50], model[5]
# -----------Style Loss : 0.010719
# step: [50], model[0]
# -----------Style Loss : 0.001942
# step: [50], model[1]
# -----------Style Loss : 0.003689
# step: [50], model[2]
# -----------Style Loss : 0.005179
# step: [50], model[3]
# -----------Style Loss : 0.006475
# step: [50], model[4]
# -----------Style Loss : 0.008144
# step: [50], model[5]
# -----------Style Loss : 0.010714
# step: [50], model[0]
# -----------Style Loss : 0.001940
# step: [50], model[1]
# -----------Style Loss : 0.003687
# step: [50], model[2]
# -----------Style Loss : 0.005175
# step: [50], model[3]
# -----------Style Loss : 0.006471
# step: [50], model[4]
# -----------Style Loss : 0.008140
# step: [50], model[5]
# -----------Style Loss : 0.010710
# step: [50], model[0]
# -----------Style Loss : 0.001939
# step: [50], model[1]
# -----------Style Loss : 0.003685
# step: [50], model[2]
# -----------Style Loss : 0.005173
# step: [50], model[3]
# -----------Style Loss : 0.006469
# step: [50], model[4]
# -----------Style Loss : 0.008137
# step: [50], model[5]
# -----------Style Loss : 0.010705
# step: [50], model[0]
# -----------Style Loss : 0.001938
# step: [50], model[1]
# -----------Style Loss : 0.003684
# step: [50], model[2]
# -----------Style Loss : 0.005170
# step: [50], model[3]
# -----------Style Loss : 0.006466
# step: [50], model[4]
# -----------Style Loss : 0.008133
# step: [50], model[5]
# -----------Style Loss : 0.010701
# step: [50], model[0]
# -----------Style Loss : 0.001939
# step: [50], model[1]
# -----------Style Loss : 0.003684
# step: [50], model[2]
# -----------Style Loss : 0.005169
# step: [50], model[3]
# -----------Style Loss : 0.006464
# step: [50], model[4]
# -----------Style Loss : 0.008130
# step: [50], model[5]
# -----------Style Loss : 0.010697
# step: [50], model[0]
# -----------Style Loss : 0.001938
# step: [50], model[1]
# -----------Style Loss : 0.003682
# step: [50], model[2]
# -----------Style Loss : 0.005168
# step: [50], model[3]
# -----------Style Loss : 0.006462
# step: [50], model[4]
# -----------Style Loss : 0.008127
# step: [50], model[5]
# -----------Style Loss : 0.010693
# step: [50], model[0]
# -----------Style Loss : 0.001937
# step: [50], model[1]
# -----------Style Loss : 0.003681
# step: [50], model[2]
# -----------Style Loss : 0.005166
# step: [50], model[3]
# -----------Style Loss : 0.006461
# step: [50], model[4]
# -----------Style Loss : 0.008125
# step: [50], model[5]
# -----------Style Loss : 0.010689
# step: [50], model[0]
# -----------Style Loss : 0.001935
# step: [50], model[1]
# -----------Style Loss : 0.003679
# step: [50], model[2]
# -----------Style Loss : 0.005163
# step: [50], model[3]
# -----------Style Loss : 0.006457
# step: [50], model[4]
# -----------Style Loss : 0.008120
# step: [50], model[5]
# -----------Style Loss : 0.010684
# step: [50], model[0]
# -----------Style Loss : 0.001935
# step: [50], model[1]
# -----------Style Loss : 0.003678
# step: [50], model[2]
# -----------Style Loss : 0.005162
# step: [50], model[3]
# -----------Style Loss : 0.006455
# step: [50], model[4]
# -----------Style Loss : 0.008117
# step: [50], model[5]
# -----------Style Loss : 0.010680
# step: [50], model[0]
# -----------Style Loss : 0.001934
# step: [50], model[1]
# -----------Style Loss : 0.003676
# step: [50], model[2]
# -----------Style Loss : 0.005159
# step: [50], model[3]
# -----------Style Loss : 0.006451
# step: [50], model[4]
# -----------Style Loss : 0.008113
# step: [50], model[5]
# -----------Style Loss : 0.010675
# Current step Number =  51
# numStreams =  6
# Current step Number =  52
# numStreams =  6
# Current step Number =  53
# numStreams =  6
# Current step Number =  54
# numStreams =  6
# Current step Number =  55
# numStreams =  6
# Current step Number =  56
# numStreams =  6
# Current step Number =  57
# numStreams =  6
# Current step Number =  58
# numStreams =  6
# Current step Number =  59
# numStreams =  6
# Current step Number =  60
# numStreams =  6
# step: [60], model[0]
# -----------Style Loss : 0.001765
# step: [60], model[1]
# -----------Style Loss : 0.003358
# step: [60], model[2]
# -----------Style Loss : 0.004720
# step: [60], model[3]
# -----------Style Loss : 0.005914
# step: [60], model[4]
# -----------Style Loss : 0.007429
# step: [60], model[5]
# -----------Style Loss : 0.009801
# step: [60], model[0]
# -----------Style Loss : 0.001764
# step: [60], model[1]
# -----------Style Loss : 0.003355
# step: [60], model[2]
# -----------Style Loss : 0.004717
# step: [60], model[3]
# -----------Style Loss : 0.005910
# step: [60], model[4]
# -----------Style Loss : 0.007425
# step: [60], model[5]
# -----------Style Loss : 0.009796
# step: [60], model[0]
# -----------Style Loss : 0.001764
# step: [60], model[1]
# -----------Style Loss : 0.003354
# step: [60], model[2]
# -----------Style Loss : 0.004715
# step: [60], model[3]
# -----------Style Loss : 0.005908
# step: [60], model[4]
# -----------Style Loss : 0.007422
# step: [60], model[5]
# -----------Style Loss : 0.009791
# step: [60], model[0]
# -----------Style Loss : 0.001763
# step: [60], model[1]
# -----------Style Loss : 0.003352
# step: [60], model[2]
# -----------Style Loss : 0.004713
# step: [60], model[3]
# -----------Style Loss : 0.005905
# step: [60], model[4]
# -----------Style Loss : 0.007418
# step: [60], model[5]
# -----------Style Loss : 0.009786
# step: [60], model[0]
# -----------Style Loss : 0.001762
# step: [60], model[1]
# -----------Style Loss : 0.003349
# step: [60], model[2]
# -----------Style Loss : 0.004709
# step: [60], model[3]
# -----------Style Loss : 0.005900
# step: [60], model[4]
# -----------Style Loss : 0.007413
# step: [60], model[5]
# -----------Style Loss : 0.009781
# step: [60], model[0]
# -----------Style Loss : 0.001761
# step: [60], model[1]
# -----------Style Loss : 0.003347
# step: [60], model[2]
# -----------Style Loss : 0.004707
# step: [60], model[3]
# -----------Style Loss : 0.005897
# step: [60], model[4]
# -----------Style Loss : 0.007409
# step: [60], model[5]
# -----------Style Loss : 0.009775
# step: [60], model[0]
# -----------Style Loss : 0.001760
# step: [60], model[1]
# -----------Style Loss : 0.003345
# step: [60], model[2]
# -----------Style Loss : 0.004704
# step: [60], model[3]
# -----------Style Loss : 0.005894
# step: [60], model[4]
# -----------Style Loss : 0.007405
# step: [60], model[5]
# -----------Style Loss : 0.009770
# step: [60], model[0]
# -----------Style Loss : 0.001758
# step: [60], model[1]
# -----------Style Loss : 0.003343
# step: [60], model[2]
# -----------Style Loss : 0.004701
# step: [60], model[3]
# -----------Style Loss : 0.005891
# step: [60], model[4]
# -----------Style Loss : 0.007401
# step: [60], model[5]
# -----------Style Loss : 0.009764
# step: [60], model[0]
# -----------Style Loss : 0.001757
# step: [60], model[1]
# -----------Style Loss : 0.003341
# step: [60], model[2]
# -----------Style Loss : 0.004698
# step: [60], model[3]
# -----------Style Loss : 0.005887
# step: [60], model[4]
# -----------Style Loss : 0.007397
# step: [60], model[5]
# -----------Style Loss : 0.009759
# step: [60], model[0]
# -----------Style Loss : 0.001757
# step: [60], model[1]
# -----------Style Loss : 0.003340
# step: [60], model[2]
# -----------Style Loss : 0.004697
# step: [60], model[3]
# -----------Style Loss : 0.005885
# step: [60], model[4]
# -----------Style Loss : 0.007393
# step: [60], model[5]
# -----------Style Loss : 0.009754
# step: [60], model[0]
# -----------Style Loss : 0.001756
# step: [60], model[1]
# -----------Style Loss : 0.003338
# step: [60], model[2]
# -----------Style Loss : 0.004693
# step: [60], model[3]
# -----------Style Loss : 0.005880
# step: [60], model[4]
# -----------Style Loss : 0.007388
# step: [60], model[5]
# -----------Style Loss : 0.009748
# step: [60], model[0]
# -----------Style Loss : 0.001755
# step: [60], model[1]
# -----------Style Loss : 0.003336
# step: [60], model[2]
# -----------Style Loss : 0.004691
# step: [60], model[3]
# -----------Style Loss : 0.005877
# step: [60], model[4]
# -----------Style Loss : 0.007384
# step: [60], model[5]
# -----------Style Loss : 0.009743
# step: [60], model[0]
# -----------Style Loss : 0.001753
# step: [60], model[1]
# -----------Style Loss : 0.003333
# step: [60], model[2]
# -----------Style Loss : 0.004688
# step: [60], model[3]
# -----------Style Loss : 0.005874
# step: [60], model[4]
# -----------Style Loss : 0.007380
# step: [60], model[5]
# -----------Style Loss : 0.009738
# step: [60], model[0]
# -----------Style Loss : 0.001752
# step: [60], model[1]
# -----------Style Loss : 0.003331
# step: [60], model[2]
# -----------Style Loss : 0.004685
# step: [60], model[3]
# -----------Style Loss : 0.005871
# step: [60], model[4]
# -----------Style Loss : 0.007375
# step: [60], model[5]
# -----------Style Loss : 0.009732
# step: [60], model[0]
# -----------Style Loss : 0.001750
# step: [60], model[1]
# -----------Style Loss : 0.003329
# step: [60], model[2]
# -----------Style Loss : 0.004681
# step: [60], model[3]
# -----------Style Loss : 0.005867
# step: [60], model[4]
# -----------Style Loss : 0.007370
# step: [60], model[5]
# -----------Style Loss : 0.009727
# step: [60], model[0]
# -----------Style Loss : 0.001750
# step: [60], model[1]
# -----------Style Loss : 0.003327
# step: [60], model[2]
# -----------Style Loss : 0.004679
# step: [60], model[3]
# -----------Style Loss : 0.005864
# step: [60], model[4]
# -----------Style Loss : 0.007366
# step: [60], model[5]
# -----------Style Loss : 0.009721
# step: [60], model[0]
# -----------Style Loss : 0.001749
# step: [60], model[1]
# -----------Style Loss : 0.003325
# step: [60], model[2]
# -----------Style Loss : 0.004676
# step: [60], model[3]
# -----------Style Loss : 0.005861
# step: [60], model[4]
# -----------Style Loss : 0.007362
# step: [60], model[5]
# -----------Style Loss : 0.009715
# step: [60], model[0]
# -----------Style Loss : 0.001748
# step: [60], model[1]
# -----------Style Loss : 0.003323
# step: [60], model[2]
# -----------Style Loss : 0.004673
# step: [60], model[3]
# -----------Style Loss : 0.005857
# step: [60], model[4]
# -----------Style Loss : 0.007357
# step: [60], model[5]
# -----------Style Loss : 0.009710
# step: [60], model[0]
# -----------Style Loss : 0.001747
# step: [60], model[1]
# -----------Style Loss : 0.003321
# step: [60], model[2]
# -----------Style Loss : 0.004671
# step: [60], model[3]
# -----------Style Loss : 0.005854
# step: [60], model[4]
# -----------Style Loss : 0.007353
# step: [60], model[5]
# -----------Style Loss : 0.009705
# step: [60], model[0]
# -----------Style Loss : 0.001745
# step: [60], model[1]
# -----------Style Loss : 0.003318
# step: [60], model[2]
# -----------Style Loss : 0.004667
# step: [60], model[3]
# -----------Style Loss : 0.005850
# step: [60], model[4]
# -----------Style Loss : 0.007349
# step: [60], model[5]
# -----------Style Loss : 0.009699
# Current step Number =  61
# numStreams =  6
# Current step Number =  62
# numStreams =  6
# Current step Number =  63
# numStreams =  6
# Current step Number =  64
# numStreams =  6
# Current step Number =  65
# numStreams =  6
# Current step Number =  66
# numStreams =  6
# Current step Number =  67
# numStreams =  6
# Current step Number =  68
# numStreams =  6
# Current step Number =  69
# numStreams =  6
# Current step Number =  70
# numStreams =  6
# step: [70], model[0]
# -----------Style Loss : 0.001535
# step: [70], model[1]
# -----------Style Loss : 0.002938
# step: [70], model[2]
# -----------Style Loss : 0.004138
# step: [70], model[3]
# -----------Style Loss : 0.005199
# step: [70], model[4]
# -----------Style Loss : 0.006541
# step: [70], model[5]
# -----------Style Loss : 0.008699
# step: [70], model[0]
# -----------Style Loss : 0.001534
# step: [70], model[1]
# -----------Style Loss : 0.002936
# step: [70], model[2]
# -----------Style Loss : 0.004135
# step: [70], model[3]
# -----------Style Loss : 0.005195
# step: [70], model[4]
# -----------Style Loss : 0.006537
# step: [70], model[5]
# -----------Style Loss : 0.008693
# step: [70], model[0]
# -----------Style Loss : 0.001532
# step: [70], model[1]
# -----------Style Loss : 0.002933
# step: [70], model[2]
# -----------Style Loss : 0.004132
# step: [70], model[3]
# -----------Style Loss : 0.005191
# step: [70], model[4]
# -----------Style Loss : 0.006532
# step: [70], model[5]
# -----------Style Loss : 0.008687
# step: [70], model[0]
# -----------Style Loss : 0.001531
# step: [70], model[1]
# -----------Style Loss : 0.002931
# step: [70], model[2]
# -----------Style Loss : 0.004128
# step: [70], model[3]
# -----------Style Loss : 0.005187
# step: [70], model[4]
# -----------Style Loss : 0.006527
# ...
# -----------Style Loss : 0.002336
# step: [130], model[4]
# -----------Style Loss : 0.003034
# step: [130], model[5]
# -----------Style Loss : 0.004420
# step: [130], model[0]
# -----------Style Loss : 0.000662
# step: [130], model[1]
# -----------Style Loss : 0.001274
# step: [130], model[2]
# -----------Style Loss : 0.001819
# step: [130], model[3]
# -----------Style Loss : 0.002336
# step: [130], model[4]
# -----------Style Loss : 0.003033
# step: [130], model[5]
# -----------Style Loss : 0.004419
# step: [130], model[0]
# -----------Style Loss : 0.000661
# step: [130], model[1]
# -----------Style Loss : 0.001274
# step: [130], model[2]
# -----------Style Loss : 0.001818
# step: [130], model[3]
# -----------Style Loss : 0.002335
# step: [130], model[4]
# -----------Style Loss : 0.003032
# step: [130], model[5]
# -----------Style Loss : 0.004418
# step: [130], model[0]
# -----------Style Loss : 0.000661
# step: [130], model[1]
# -----------Style Loss : 0.001273
# step: [130], model[2]
# -----------Style Loss : 0.001818
# step: [130], model[3]
# -----------Style Loss : 0.002335
# step: [130], model[4]
# -----------Style Loss : 0.003032
# step: [130], model[5]
# -----------Style Loss : 0.004418
# step: [130], model[0]
# -----------Style Loss : 0.000661
# step: [130], model[1]
# -----------Style Loss : 0.001272
# step: [130], model[2]
# -----------Style Loss : 0.001817
# step: [130], model[3]
# -----------Style Loss : 0.002333
# step: [130], model[4]
# -----------Style Loss : 0.003030
# step: [130], model[5]
# -----------Style Loss : 0.004416
# step: [130], model[0]
# -----------Style Loss : 0.000661
# step: [130], model[1]
# -----------Style Loss : 0.001272
# step: [130], model[2]
# -----------Style Loss : 0.001816
# step: [130], model[3]
# -----------Style Loss : 0.002333
# step: [130], model[4]
# -----------Style Loss : 0.003030
# step: [130], model[5]
# -----------Style Loss : 0.004415
# Current step Number =  131
# numStreams =  6
# Current step Number =  132
# numStreams =  6
# Current step Number =  133
# numStreams =  6
# Current step Number =  134
# numStreams =  6
# Current step Number =  135
# numStreams =  6
# Current step Number =  136
# numStreams =  6
# Current step Number =  137
# numStreams =  6
# Current step Number =  138
# numStreams =  6
# Current step Number =  139
# numStreams =  6
# Current step Number =  140
# numStreams =  6
# step: [140], model[0]
# -----------Style Loss : 0.000622
# step: [140], model[1]
# -----------Style Loss : 0.001200
# step: [140], model[2]
# -----------Style Loss : 0.001713
# step: [140], model[3]
# -----------Style Loss : 0.002205
# step: [140], model[4]
# -----------Style Loss : 0.002874
# step: [140], model[5]
# -----------Style Loss : 0.004230
# step: [140], model[0]
# -----------Style Loss : 0.000621
# step: [140], model[1]
# -----------Style Loss : 0.001199
# step: [140], model[2]
# -----------Style Loss : 0.001712
# step: [140], model[3]
# -----------Style Loss : 0.002203
# step: [140], model[4]
# -----------Style Loss : 0.002872
# step: [140], model[5]
# -----------Style Loss : 0.004229
# step: [140], model[0]
# -----------Style Loss : 0.000621
# step: [140], model[1]
# -----------Style Loss : 0.001198
# step: [140], model[2]
# -----------Style Loss : 0.001711
# step: [140], model[3]
# -----------Style Loss : 0.002203
# step: [140], model[4]
# -----------Style Loss : 0.002871
# step: [140], model[5]
# -----------Style Loss : 0.004228
# step: [140], model[0]
# -----------Style Loss : 0.000621
# step: [140], model[1]
# -----------Style Loss : 0.001198
# step: [140], model[2]
# -----------Style Loss : 0.001711
# step: [140], model[3]
# -----------Style Loss : 0.002202
# step: [140], model[4]
# -----------Style Loss : 0.002870
# step: [140], model[5]
# -----------Style Loss : 0.004226
# step: [140], model[0]
# -----------Style Loss : 0.000621
# step: [140], model[1]
# -----------Style Loss : 0.001198
# step: [140], model[2]
# -----------Style Loss : 0.001711
# step: [140], model[3]
# -----------Style Loss : 0.002202
# step: [140], model[4]
# -----------Style Loss : 0.002870
# step: [140], model[5]
# -----------Style Loss : 0.004226
# step: [140], model[0]
# -----------Style Loss : 0.000620
# step: [140], model[1]
# -----------Style Loss : 0.001197
# step: [140], model[2]
# -----------Style Loss : 0.001710
# step: [140], model[3]
# -----------Style Loss : 0.002201
# step: [140], model[4]
# -----------Style Loss : 0.002869
# step: [140], model[5]
# -----------Style Loss : 0.004225
# step: [140], model[0]
# -----------Style Loss : 0.000620
# step: [140], model[1]
# -----------Style Loss : 0.001197
# step: [140], model[2]
# -----------Style Loss : 0.001709
# step: [140], model[3]
# -----------Style Loss : 0.002200
# step: [140], model[4]
# -----------Style Loss : 0.002868
# step: [140], model[5]
# -----------Style Loss : 0.004224
# step: [140], model[0]
# -----------Style Loss : 0.000620
# step: [140], model[1]
# -----------Style Loss : 0.001196
# step: [140], model[2]
# -----------Style Loss : 0.001708
# step: [140], model[3]
# -----------Style Loss : 0.002199
# step: [140], model[4]
# -----------Style Loss : 0.002867
# step: [140], model[5]
# -----------Style Loss : 0.004222
# step: [140], model[0]
# -----------Style Loss : 0.000620
# step: [140], model[1]
# -----------Style Loss : 0.001197
# step: [140], model[2]
# -----------Style Loss : 0.001708
# step: [140], model[3]
# -----------Style Loss : 0.002199
# step: [140], model[4]
# -----------Style Loss : 0.002867
# step: [140], model[5]
# -----------Style Loss : 0.004222
# step: [140], model[0]
# -----------Style Loss : 0.000620
# step: [140], model[1]
# -----------Style Loss : 0.001196
# step: [140], model[2]
# -----------Style Loss : 0.001707
# step: [140], model[3]
# -----------Style Loss : 0.002198
# step: [140], model[4]
# -----------Style Loss : 0.002866
# step: [140], model[5]
# -----------Style Loss : 0.004221
# step: [140], model[0]
# -----------Style Loss : 0.000620
# step: [140], model[1]
# -----------Style Loss : 0.001196
# step: [140], model[2]
# -----------Style Loss : 0.001707
# step: [140], model[3]
# -----------Style Loss : 0.002197
# step: [140], model[4]
# -----------Style Loss : 0.002865
# step: [140], model[5]
# -----------Style Loss : 0.004220
# step: [140], model[0]
# -----------Style Loss : 0.000619
# step: [140], model[1]
# -----------Style Loss : 0.001195
# step: [140], model[2]
# -----------Style Loss : 0.001706
# step: [140], model[3]
# -----------Style Loss : 0.002197
# step: [140], model[4]
# -----------Style Loss : 0.002864
# step: [140], model[5]
# -----------Style Loss : 0.004219
# step: [140], model[0]
# -----------Style Loss : 0.000619
# step: [140], model[1]
# -----------Style Loss : 0.001195
# step: [140], model[2]
# -----------Style Loss : 0.001706
# step: [140], model[3]
# -----------Style Loss : 0.002196
# step: [140], model[4]
# -----------Style Loss : 0.002863
# step: [140], model[5]
# -----------Style Loss : 0.004218
# step: [140], model[0]
# -----------Style Loss : 0.000619
# step: [140], model[1]
# -----------Style Loss : 0.001194
# step: [140], model[2]
# -----------Style Loss : 0.001705
# step: [140], model[3]
# -----------Style Loss : 0.002195
# step: [140], model[4]
# -----------Style Loss : 0.002862
# step: [140], model[5]
# -----------Style Loss : 0.004217
# step: [140], model[0]
# -----------Style Loss : 0.000619
# step: [140], model[1]
# -----------Style Loss : 0.001194
# step: [140], model[2]
# -----------Style Loss : 0.001705
# step: [140], model[3]
# -----------Style Loss : 0.002195
# step: [140], model[4]
# -----------Style Loss : 0.002861
# step: [140], model[5]
# -----------Style Loss : 0.004216
# step: [140], model[0]
# -----------Style Loss : 0.000618
# step: [140], model[1]
# -----------Style Loss : 0.001194
# step: [140], model[2]
# -----------Style Loss : 0.001704
# step: [140], model[3]
# -----------Style Loss : 0.002194
# step: [140], model[4]
# -----------Style Loss : 0.002861
# step: [140], model[5]
# -----------Style Loss : 0.004215
# step: [140], model[0]
# -----------Style Loss : 0.000619
# step: [140], model[1]
# -----------Style Loss : 0.001193
# step: [140], model[2]
# -----------Style Loss : 0.001704
# step: [140], model[3]
# -----------Style Loss : 0.002193
# step: [140], model[4]
# -----------Style Loss : 0.002860
# step: [140], model[5]
# -----------Style Loss : 0.004214
# step: [140], model[0]
# -----------Style Loss : 0.000618
# step: [140], model[1]
# -----------Style Loss : 0.001193
# step: [140], model[2]
# -----------Style Loss : 0.001703
# step: [140], model[3]
# -----------Style Loss : 0.002193
# step: [140], model[4]
# -----------Style Loss : 0.002859
# step: [140], model[5]
# -----------Style Loss : 0.004213
# step: [140], model[0]
# -----------Style Loss : 0.000618
# step: [140], model[1]
# -----------Style Loss : 0.001192
# step: [140], model[2]
# -----------Style Loss : 0.001702
# step: [140], model[3]
# -----------Style Loss : 0.002192
# step: [140], model[4]
# -----------Style Loss : 0.002858
# step: [140], model[5]
# -----------Style Loss : 0.004212
# step: [140], model[0]
# -----------Style Loss : 0.000618
# step: [140], model[1]
# -----------Style Loss : 0.001192
# step: [140], model[2]
# -----------Style Loss : 0.001702
# step: [140], model[3]
# -----------Style Loss : 0.002191
# step: [140], model[4]
# -----------Style Loss : 0.002857
# step: [140], model[5]
# -----------Style Loss : 0.004211
# Current step Number =  141
# numStreams =  6
# Current step Number =  142
# numStreams =  6
# Current step Number =  143
# numStreams =  6
# Current step Number =  144
# numStreams =  6
# Current step Number =  145
# numStreams =  6
# Current step Number =  146
# numStreams =  6
# Current step Number =  147
# numStreams =  6
# Current step Number =  148
# numStreams =  6
# Current step Number =  149
# numStreams =  6
# Current step Number =  150
# numStreams =  6
# step: [150], model[0]
# -----------Style Loss : 0.000583
# step: [150], model[1]
# -----------Style Loss : 0.001120
# step: [150], model[2]
# -----------Style Loss : 0.001601
# step: [150], model[3]
# -----------Style Loss : 0.002065
# step: [150], model[4]
# -----------Style Loss : 0.002704
# step: [150], model[5]
# -----------Style Loss : 0.004031
# step: [150], model[0]
# -----------Style Loss : 0.000583
# step: [150], model[1]
# -----------Style Loss : 0.001120
# step: [150], model[2]
# -----------Style Loss : 0.001601
# step: [150], model[3]
# -----------Style Loss : 0.002065
# step: [150], model[4]
# -----------Style Loss : 0.002703
# step: [150], model[5]
# -----------Style Loss : 0.004029
# step: [150], model[0]
# -----------Style Loss : 0.000583
# step: [150], model[1]
# -----------Style Loss : 0.001120
# step: [150], model[2]
# -----------Style Loss : 0.001600
# step: [150], model[3]
# -----------Style Loss : 0.002064
# step: [150], model[4]
# -----------Style Loss : 0.002702
# step: [150], model[5]
# -----------Style Loss : 0.004028
# step: [150], model[0]
# -----------Style Loss : 0.000583
# step: [150], model[1]
# -----------Style Loss : 0.001119
# step: [150], model[2]
# -----------Style Loss : 0.001600
# step: [150], model[3]
# -----------Style Loss : 0.002063
# step: [150], model[4]
# -----------Style Loss : 0.002702
# step: [150], model[5]
# -----------Style Loss : 0.004028
# step: [150], model[0]
# -----------Style Loss : 0.000582
# step: [150], model[1]
# -----------Style Loss : 0.001118
# step: [150], model[2]
# -----------Style Loss : 0.001599
# step: [150], model[3]
# -----------Style Loss : 0.002062
# step: [150], model[4]
# -----------Style Loss : 0.002701
# step: [150], model[5]
# -----------Style Loss : 0.004026
# step: [150], model[0]
# -----------Style Loss : 0.000582
# step: [150], model[1]
# -----------Style Loss : 0.001119
# step: [150], model[2]
# -----------Style Loss : 0.001599
# step: [150], model[3]
# -----------Style Loss : 0.002062
# step: [150], model[4]
# -----------Style Loss : 0.002701
# step: [150], model[5]
# -----------Style Loss : 0.004026
# step: [150], model[0]
# -----------Style Loss : 0.000582
# step: [150], model[1]
# -----------Style Loss : 0.001118
# step: [150], model[2]
# -----------Style Loss : 0.001598
# step: [150], model[3]
# -----------Style Loss : 0.002061
# step: [150], model[4]
# -----------Style Loss : 0.002700
# step: [150], model[5]
# -----------Style Loss : 0.004025
# step: [150], model[0]
# -----------Style Loss : 0.000582
# step: [150], model[1]
# -----------Style Loss : 0.001118
# step: [150], model[2]
# -----------Style Loss : 0.001598
# step: [150], model[3]
# -----------Style Loss : 0.002061
# step: [150], model[4]
# -----------Style Loss : 0.002699
# step: [150], model[5]
# -----------Style Loss : 0.004024
# step: [150], model[0]
# -----------Style Loss : 0.000581
# step: [150], model[1]
# -----------Style Loss : 0.001117
# step: [150], model[2]
# -----------Style Loss : 0.001597
# step: [150], model[3]
# -----------Style Loss : 0.002060
# step: [150], model[4]
# -----------Style Loss : 0.002698
# step: [150], model[5]
# -----------Style Loss : 0.004023
# step: [150], model[0]
# -----------Style Loss : 0.000581
# step: [150], model[1]
# -----------Style Loss : 0.001117
# step: [150], model[2]
# -----------Style Loss : 0.001597
# step: [150], model[3]
# -----------Style Loss : 0.002060
# step: [150], model[4]
# -----------Style Loss : 0.002697
# step: [150], model[5]
# -----------Style Loss : 0.004022
# step: [150], model[0]
# -----------Style Loss : 0.000581
# step: [150], model[1]
# -----------Style Loss : 0.001117
# step: [150], model[2]
# -----------Style Loss : 0.001596
# step: [150], model[3]
# -----------Style Loss : 0.002059
# step: [150], model[4]
# -----------Style Loss : 0.002696
# step: [150], model[5]
# -----------Style Loss : 0.004021
# step: [150], model[0]
# -----------Style Loss : 0.000581
# step: [150], model[1]
# -----------Style Loss : 0.001117
# step: [150], model[2]
# -----------Style Loss : 0.001596
# step: [150], model[3]
# -----------Style Loss : 0.002059
# step: [150], model[4]
# -----------Style Loss : 0.002696
# step: [150], model[5]
# -----------Style Loss : 0.004021
# step: [150], model[0]
# -----------Style Loss : 0.000581
# step: [150], model[1]
# -----------Style Loss : 0.001116
# step: [150], model[2]
# -----------Style Loss : 0.001595
# step: [150], model[3]
# -----------Style Loss : 0.002058
# step: [150], model[4]
# -----------Style Loss : 0.002696
# step: [150], model[5]
# -----------Style Loss : 0.004020
# step: [150], model[0]
# -----------Style Loss : 0.000581
# step: [150], model[1]
# -----------Style Loss : 0.001116
# step: [150], model[2]
# -----------Style Loss : 0.001595
# step: [150], model[3]
# -----------Style Loss : 0.002058
# step: [150], model[4]
# -----------Style Loss : 0.002695
# step: [150], model[5]
# -----------Style Loss : 0.004020
# step: [150], model[0]
# -----------Style Loss : 0.000580
# step: [150], model[1]
# -----------Style Loss : 0.001115
# step: [150], model[2]
# -----------Style Loss : 0.001594
# step: [150], model[3]
# -----------Style Loss : 0.002056
# step: [150], model[4]
# -----------Style Loss : 0.002694
# step: [150], model[5]
# -----------Style Loss : 0.004018
# step: [150], model[0]
# -----------Style Loss : 0.000580
# step: [150], model[1]
# -----------Style Loss : 0.001115
# step: [150], model[2]
# -----------Style Loss : 0.001593
# step: [150], model[3]
# -----------Style Loss : 0.002055
# step: [150], model[4]
# -----------Style Loss : 0.002693
# step: [150], model[5]
# -----------Style Loss : 0.004017
# step: [150], model[0]
# -----------Style Loss : 0.000580
# step: [150], model[1]
# -----------Style Loss : 0.001115
# step: [150], model[2]
# -----------Style Loss : 0.001593
# step: [150], model[3]
# -----------Style Loss : 0.002056
# step: [150], model[4]
# -----------Style Loss : 0.002692
# step: [150], model[5]
# -----------Style Loss : 0.004016
# step: [150], model[0]
# -----------Style Loss : 0.000580
# step: [150], model[1]
# -----------Style Loss : 0.001115
# step: [150], model[2]
# -----------Style Loss : 0.001593
# step: [150], model[3]
# -----------Style Loss : 0.002055
# step: [150], model[4]
# -----------Style Loss : 0.002692
# step: [150], model[5]
# -----------Style Loss : 0.004015
# step: [150], model[0]
# -----------Style Loss : 0.000580
# step: [150], model[1]
# -----------Style Loss : 0.001114
# step: [150], model[2]
# -----------Style Loss : 0.001593
# step: [150], model[3]
# -----------Style Loss : 0.002054
# step: [150], model[4]
# -----------Style Loss : 0.002691
# step: [150], model[5]
# -----------Style Loss : 0.004015
# step: [150], model[0]
# -----------Style Loss : 0.000580
# step: [150], model[1]
# -----------Style Loss : 0.001114
# step: [150], model[2]
# -----------Style Loss : 0.001592
# step: [150], model[3]
# -----------Style Loss : 0.002053
# step: [150], model[4]
# -----------Style Loss : 0.002690
# step: [150], model[5]
# -----------Style Loss : 0.004013
# Current step Number =  151
# numStreams =  6
# (257, 867)
# Output range: -0.49605522 2.5543952
# mean and sigma: 0.06114468 0.19171594

# %%
#SPECTOFFSET
SPECTOFFSET=0

##out_spec = inv_scale(out,shf)
for j in range(len(outputs)):
    print(f'Min/Max of outputs:  {np.amin(outputs[j])},{np.amax(outputs[j])}') # check values make sense
    fig = plt.figure()
    plt.title('Style spectrogram')
    ax = fig.add_subplot(111)
    n,b,_ = ax.hist(outputs[j].flatten(),bins='auto')
    plt.show()

if tifresi :
    #### Shift log spec to use max range before thresholding for tfresi inversion
    #outputs=[x+1-np.amax(x) for x in outputs]
    print('TIFResi: inv_log_spectrogram')
    if use01scale == True:
        foo = [img_invscale(x,a_min,a_max,0,1) for x in outputs]
        
        out_spec = [inv_log_spectrogram(x+SPECTOFFSET) for x in foo]

        for j in range(len(outputs)):
            print(f'   RESCALED: Min/Max of outputs:  {np.amin(foo[j])},{np.amax(foo[j])}') # check values make sense

    else:
        out_spec = [inv_log_spectrogram(x+SPECTOFFSET) for x in outputs] 

        #out_spec = [inv_log(x+SPECTOFFSET) for x in outputs]
        for j in range(len(outputs)):
            print(f'   inv_log_spectrogram: Min/Max of outputs:  {np.amin(out_spec[j])},{np.amax(out_spec[j])}') # check values make sense

else : 
    print('HUZ: inv_log')
    if use01scale == True:
        out_spec = [inv_log(img_invscale(x,a_min,a_max,0,1)) for x in outputs]
    else:
        out_spec = [inv_log(x) for x in outputs]

    for j in range(len(out_spec)):
        print(f'Min/Max of out_spec: {np.amin(out_spec[j])}, {np.amax(out_spec[j])}') # check values make sense
# Out:
# Min/Max of outputs:  -0.4960552155971527,2.5543951988220215
# HUZ: inv_log
# Min/Max of out_spec: -0.39107197523117065, 11.863516807556152

# %%
# Griffin & Lim algo for phase reconstruction (not used for tifresi)

print(f'out_spec lene is {len(out_spec)}')
for index,value in enumerate(out_spec):

    print(f'shape of value is {value.shape}')
    
    if tifresi :
        print(f'TIFResi invert mag to audio')
        print("shape of mag = ",np.shape(value))
        S = value
        bar=S#-np.amin(S)+.0001
#         bar = np.abs(bar)
        #bar=bar/np.amax(bar)
        bar = np.clip(bar, 0,None)
        print(f'Min/Max of spectrogram: {np.amin(bar)}, {np.amax(bar)}') # check values make sense
        x = stft_system.invert_spectrogram(bar) 
    else :
        print(f'Huz invert mag to audio')
        p = 2 * np.pi * np.random.random_sample(value.shape) - np.pi #start with some phase
        #Griffin Lim
        for i in range(50):
            S = value * np.exp(1j*p) #use magnitude a given by spectrogram and some random phase
            x = librosa.istft(S,hop_length=K_HOP, win_length=N_FFT, center=False) #do the inverse transform
            p = np.angle(librosa.stft(x, n_fft=N_FFT, hop_length=K_HOP, win_length=N_FFT, center=False)) #use this new phase value

    try:
        os.makedirs("outputs/" + outname)
    except FileExistsError:
        # directory already exists
        pass

    
    yshape, xshape = value.shape
    x_positions = np.arange(0,xshape,K_HOP/2-1.5) # pixel count at label position
    x_labels=x_positions*K_HOP/16000

    y_positions=np.arange(0, yshape,64)
    freqsperbin=16000/(2*(yshape-1))
    y_labels=y_positions*freqsperbin
    
    #yshape, xshape = value.shape
    #num_labels=10
    #step_x = int(xshape / (num_labels - 1)) # step between consecutive labels
    #x_positions = np.arange(0,xshape,step_x) # pixel count at label position
    #x_labels=x_positions*K_HOP/16000


    OUTPUT_FILENAME="outputs/" + outname + '/' + outname + '_' + str(index) + '.wav'
    #librosa.output.write_wav("outputs/" + outname + '/' + outname + '_' + str(index) + '.wav', x, fs)
    sf.write(OUTPUT_FILENAME, x, fs)
    print(f'Spectrogram values range over [{np.amin(value)},{np.amax(value)} ]')
    #figure(figsize=(8, 6), dpi=80)
    plt.figure().set_size_inches(20, 4)
    plt.title('Style only reconstruction from Gram Matrices')
    plt.imshow(value,  origin='lower', cmap=plt.cm.get_cmap('Oranges'))
    plt.colorbar();
    plt.xticks(x_positions, x_labels)
    plt.xlabel("time (secs)")
    plt.yticks(y_positions, y_labels)
    plt.ylabel("frequency")

    plt.clim(-0, .3);  #prevent extreme values from making spectrum practicvally invisible [where are those huge values????]
    
    OUTPUT_PNG_FILENAME="outputs/" + outname + '/' + outname + '_' + str(index) + '.png'
    plt.savefig(OUTPUT_PNG_FILENAME)

    plt.show()

plt.ioff()
# Out:
# out_spec lene is 1
# shape of value is (257, 867)
# Huz invert mag to audio
# Spectrogram values range over [-0.39107197523117065,11.863516807556152 ]

# %%
print(OUTPUT_FILENAME)
display(Audio(OUTPUT_FILENAME, autoplay=True))
# Out:
# outputs/rftests/rftests_0.wav
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
OUTPUT_FILENAME="outputs/" + outname + '/' + outname + '_' + str(index) + '.png'
plt.savefig(OUTPUT_FILENAME)

# %%
a = torch.rand(2,3)
b = torch.rand(2,3)
print(a)
print(b)
print (a+b)
# Out:
# tensor([[0.3274, 0.8950, 0.7944],
#         [0.8528, 0.4653, 0.4163]])
# tensor([[0.0518, 0.1924, 0.5494],
#         [0.1029, 0.1511, 0.1100]])
# tensor([[0.3792, 1.0874, 1.3438],
#         [0.9558, 0.6164, 0.5263]])
